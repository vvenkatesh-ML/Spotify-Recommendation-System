# %%
import spotipy
import spotipy.util as util
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy.oauth2 as oauth2
import pandas as pd
import numpy as np
import json
import matplotlib.pyplot as plt
import seaborn as sns
# %config InlineBackend.figure_format ='retina'
import random
from functools import reduce
from sklearn.ensemble import RandomForestRegressor
from datetime import date
import time

# %% [markdown]
# ## Spotify API Call

# %%
client_id = '83c1f666855f45f89b2216e55c7bf535'
client_secret = '9bfd86b3fd3c43ada84e1f282fb1df35'
redirect_uri='http://localhost:8910/callback'
username = '61d4pmnwnwjt7xz9tj6v3txho'

scope = 'user-top-read'

client_credentials_manager = SpotifyClientCredentials(client_id=client_id, 
                                                      client_secret=client_secret)
                                                      
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

token = util.prompt_for_user_token(username,scope, client_id, client_secret, redirect_uri)

if token:
    sp = spotipy.Spotify(auth=token)
else:
    print("Can't get token for", username)

# %% [markdown]
# ## Top Tracks Extraction

# %%
results = sp.current_user_top_tracks(limit=50, offset=0,time_range='short_term')

#Convert the results into a dataframe
track_name = []
track_id = []
artist = []
new = []
album = []
duration = []
popularity = []
for i, items in enumerate(results['items']):
        track_name.append(items['name'])
        track_id.append(items['id'])
        artist.append(items["artists"][0]["name"])
        duration.append(items["duration_ms"])
        album.append(items["album"]["name"])
        popularity.append(items["popularity"])

# Create the final df   
df_top_tracks = pd.DataFrame({ "track_name": track_name, 
                             "album": album, 
                             "track_id": track_id,
                             "artist": artist, 
                             "duration": duration, 
                             "popularity": popularity})

df_top_tracks
# Out:
#                                         track_name  \
# 0                                             Maps
# 1                                    Heaven's Gate
# 2                                 A September Song
# 3                              Love on the Weekend
# 4   If the World Was Ending - feat. Julia Michaels
# 5                                Perfect Strangers
# 6                                  Banana Pancakes
# 7                                        Trainsong
# 8                                    Howling Light
# 9                                  Feels Like Love
# 10                                 All the Cowboys
# 11                                       My Person
# 12                                        Comeback
# 13                    Maybe We Will - 2020 Version
# 14                         Every Girl I Ever Loved
# 15                                    Meet The Man
# 16                  Hello Beautiful - 2020 Version
# 17                                         Shallow
# 18                             Thousand - Acoustic
# 19                                           Creep
# 20                                         windows
# 21                                 OK Not To Be OK
# 22                            Just the Way You Are
# 23                                         TiK ToK
# 24                            Love The Way You Lie
# 25                                        Dynamite
# 26                        Feel Again (Feat. Au/Ra)
# 27                                     Free Spirit
# 28                                          Misery
# 29                           Be Kind (with Halsey)
# 30                                        Takeaway
# 31                                Hey, Soul Sister
# 32                   Past Life (with Selena Gomez)
# 33                                         Daisies
# 34                                          Wonder
# 35                                    Slow Grenade
# 36                                California Gurls
# 37                                   Lose Somebody
# 38                                     Bad Romance
# 39                      Drops of Jupiter (Tell Me)
#
#                                                 album                track_id  \
# 0                                                   V  4gbVRS8gloEluzf0GzDOFc
# 1                                        Desert Songs  62EuvgIqhc9o5DPqKse952
# 2                                              Demons  6BNZGQBMwlF2Zmsxcq08iC
# 3                                 Love on the Weekend  0j2WBxWZnWti5TpSxjJvPb
# 4      If the World Was Ending (feat. Julia Michaels)  2kJwzbxV2ppxnQoYw4GLBZ
# 5                                                Blue  3P3pw6C19j31Rnzgo3JG7o
# 6                                   In Between Dreams  451GvHwY99NKV4zdKPRWmv
# 7                                         Another Day  4pxW6L91xBeUrWygGcSHOe
# 8                                 Year In The Kingdom  7E6iObqRWYyzoZdgPOgdvi
# 9                                    Noah Schnacky EP  04hHPq6kXTbcSSDrdaP3s4
# 10                                    All the Cowboys  13TOvHAfdO8wryqxBL7fnI
# 25          Taio Cruz    203866          73
# 26               Kina    139354          65
# 27             Khalid    182080          76
# 28           Maroon 5    216200          58
# 29         Marshmello    172761          87
# 30   The Chainsmokers    209880          81
# 31              Train    216773          85
# 32      Trevor Daniel    186480          79
# 33         Katy Perry    173123          80
# 34       Shawn Mendes    172692          91
# 35     Ellie Goulding    217493          72
# 36         Katy Perry    234653          75
# 37               Kygo    199549          83
# 38          Lady Gaga    294573          83
# 39              Train    259933          80

# %% [markdown]
# ## Features Extraction

# %%
def get_features(sp,df):
    playlist = df[['track_id','track_name']]
    features = []
    
    features += sp.audio_features(playlist.iloc[0:50, 0])

    feature_list = []
    for feature in features:
        feature_list.append([feature['danceability'],
                        feature['energy'],
                        feature['key'],
                        feature['loudness'],
                        feature['mode'],
                        feature['speechiness'],
                        feature['acousticness'],
                        feature['instrumentalness'],
                        feature['liveness'],
                        feature['valence'],
                        feature['tempo'],
                        feature['duration_ms']]
                       )

    df_audio_feature = pd.DataFrame(feature_list, columns = ['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 
                                                          'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
                                                          'duration_ms'])
    df_playlist_audio_features = pd.concat([playlist, df_audio_feature], axis=1)
    return df_playlist_audio_features

# %%
df_final_features = get_features(sp,df_top_tracks)
#Drop the mode feature as it is binary
del df_final_features['mode']
df_final_features
# Out:
#                   track_id                                      track_name  \
# 0   4gbVRS8gloEluzf0GzDOFc                                            Maps
# 1   62EuvgIqhc9o5DPqKse952                                   Heaven's Gate
# 2   6BNZGQBMwlF2Zmsxcq08iC                                A September Song
# 3   0j2WBxWZnWti5TpSxjJvPb                             Love on the Weekend
# 4   2kJwzbxV2ppxnQoYw4GLBZ  If the World Was Ending - feat. Julia Michaels
# 5   3P3pw6C19j31Rnzgo3JG7o                               Perfect Strangers
# 6   451GvHwY99NKV4zdKPRWmv                                 Banana Pancakes
# 7   4pxW6L91xBeUrWygGcSHOe                                       Trainsong
# 8   7E6iObqRWYyzoZdgPOgdvi                                   Howling Light
# 9   04hHPq6kXTbcSSDrdaP3s4                                 Feels Like Love
# 10  13TOvHAfdO8wryqxBL7fnI                                 All the Cowboys
# 11  1MOOJuxUu9QiQE9GgkYYPb                                       My Person
# 12  1wr0HUe5tFDlN32jfwt9IS                                        Comeback
# 13  26LKaGfw6ZolgGArPDEN2R                    Maybe We Will - 2020 Version
# 14  4fbnx3oevoht9LNrauDsVP                         Every Girl I Ever Loved
# 15  54iGR32Ba6mRtwLASLkohd                                    Meet The Man
# 16  6PZR4jQ09UmM9hphbIblQQ                  Hello Beautiful - 2020 Version
# 17  6ysfrXnADdeTtW20oSybln                                         Shallow
# 18  0NSqOUjf55rgVEqN7e9fhb                             Thousand - Acoustic
# 19  0SCox9Tmm4AxcnhDXZglYB                                           Creep
# 20  0vCxilr1Z63f1XSQhu2GJN                                         windows
# 21  0zzVTGyRrWpQu8Fr28NRAv                                 OK Not To Be OK
# 22  7BqBn9nzAq8spo5e7cZ0dJ                            Just the Way You Are
# 23  0HPD5WQqrq7wPWR7P7Dw1i                                         TiK ToK
# 24  15JINEqzVMv3SvJTAXAKED                            Love The Way You Lie
# 32         0.612  0.5390    3    -5.071       0.0488      0.104000
# 33         0.639  0.5460    1    -5.382       0.0407      0.083700
# 34         0.333  0.6370    1    -4.904       0.0581      0.131000
# 35         0.758  0.5620    9    -6.302       0.0771      0.099600
# 36         0.791  0.7540    0    -3.729       0.0569      0.004460
# 37         0.580  0.5860    1    -6.883       0.0357      0.344000
# 38         0.696  0.9210    0    -3.755       0.0363      0.003140
# 39         0.468  0.6400    0    -5.862       0.0275      0.154000
#
#     instrumentalness  liveness  valence    tempo  duration_ms
# 0           0.000000    0.0590   0.8790  120.032       189960
# 1           0.008130    0.1110   0.4500  147.851       189366
# 2           0.000000    0.1010   0.0556  129.835       168000
# 3           0.002870    0.0651   0.4060  119.941       212627
# 4           0.000000    0.1090   0.6040   75.801       208687
# 5           0.000000    0.2130   0.7040  117.965       196613
# 6           0.000009    0.0933   0.6150  114.303       191907
# 7           0.000002    0.1120   0.4500  159.128       158813
# 8           0.000890    0.3590   0.2810  145.768       214640
# 9           0.000000    0.1260   0.7030  117.047       174760
# 10          0.000000    0.1780   0.4700  144.022       228232
# 11          0.000000    0.1300   0.7560  165.966       177000
# 12          0.000000    0.2180   0.6830   95.978       168240
# 13          0.000000    0.1100   0.5260   85.045       190440
# 14          0.000000    0.0964   0.5760  189.933       162891
# 15          0.000002    0.1060   0.5930  150.022       230427
# 16          0.000000    0.1820   0.2990  148.084       232240
# 17          0.000000    0.0829   0.3260   95.989       207747
# 18          0.003020    0.0703   0.1920  109.482       202720
# 19          0.000702    0.0756   0.4240   75.840       277895
# 20          0.000441    0.1320   0.2630  112.403       182093
# 21          0.000000    0.0743   0.2630  103.072       159863
# 22          0.000000    0.0876   0.4340  109.012       220733
# 23          0.000000    0.2890   0.7140  120.028       199693
# 24          0.000000    0.5200   0.6410   86.989       263373
# 25          0.000000    0.0329   0.8180  119.968       203867
# 26          0.000000    0.1240   0.2240   78.138       139355
# 27          0.000770    0.1110   0.1100  139.994       182080
# 28          0.000000    0.1990   0.7110  102.979       216200
# 29          0.000000    0.0541   0.4520   93.995       172762
# 30          0.000000    0.1010   0.3510  100.100       209880
# 31          0.000000    0.0826   0.7950   97.012       216773
# 32          0.000000    0.1800   0.2940   79.948       186480
# 33          0.000000    0.1220   0.1490  122.179       173124
# 34          0.000018    0.1490   0.1320  139.898       172693
# 35          0.000000    0.0996   0.5810  142.035       217493
# 36          0.000000    0.1630   0.4250  125.014       234653
# 37          0.000000    0.0755   0.5070  147.988       199549
# 38          0.000052    0.0842   0.7140  119.001       294573
# 39          0.000000    0.1540   0.4990   79.297       259933

# %% [markdown]
# ## EDA

# %%
df_final_features.hist(figsize=(35,25)) 
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Playlist Extraction

# %% [markdown]
# ### Featured Playlists Extraction

# %%
def featured_playlists(sp):
    id = []
    name = []
    num_tracks = []
    
    featured = sp.featured_playlists(sp)
    playlists = featured['playlists']
    for i, items in enumerate(playlists['items']):
        id.append(items['id'])
        name.append(items['name'])
        num_tracks.append(items['tracks']['total'])
    
    df_playlists = pd.DataFrame({'playlist_id':id, 'playlist_name':name, '#tracks': num_tracks})
    return df_playlists

# %%
df_featured_playlists = featured_playlists(sp)
df_featured_playlists
# Out:
#                playlist_id                  playlist_name  #tracks
# 0   37i9dQZF1DXbcPC6Vvqudd                     Night Rain      220
# 1   37i9dQZF1DX8Sz1gsYZdwj                Classical Sleep       72
# 2   37i9dQZF1DX0QKpU3cGsyb                   Bedroom Jams       69
# 3   37i9dQZF1DWVvXA824aCbn                  The Piano Bar      127
# 4   37i9dQZF1DWZd79rJ6a7lp                          Sleep      257
# 5   37i9dQZF1DWX3387IZmjNa                         B.A.E.       50
# 6   37i9dQZF1DX4sWSpwq3LiO                 Peaceful Piano      308
# 7   37i9dQZF1DWYcDQ1hSjOpY                     Deep Sleep      258
# 8   37i9dQZF1DX2UgsUIg75Vg                    Chilled R&B       50
# 9   37i9dQZF1DXbZmKskFbVct            ASMR Sleep Whispers       56
# 10  37i9dQZF1DWWSads6V2oIk  The Sleep Machine: Rainforest       42
# 11  37i9dQZF1DWUZ5bk6qqDSy                    White Noise      110

# %% [markdown]
# ### User Playlists Extraction

# %%
def user_playlist(sp,username):
    playlist_id = []
    playlist_name = []
    num_tracks = []
    
    featured = sp.user_playlists(username)
    for i, items in enumerate(featured['items']):
        playlist_id.append(items['id'])
        playlist_name.append(items['name'])
        num_tracks.append(items['tracks']['total'])
    
    df_your_lib = pd.DataFrame({'playlist_id':playlist_id, 'playlist_name':playlist_name, '#tracks': num_tracks})
    return df_your_lib

# %%
df_user_playlists = user_playlist(sp,username)
searchfor = ['Custom', 'Discover']
df_user_playlists =  df_user_playlists[~df_user_playlists['playlist_name'].str.contains('|'.join(searchfor))]
df_user_playlists
# Out:
#                playlist_id                                      playlist_name  \
# 0   37i9dQZF1DX5Ejj0EkURtP                                        All Out 10s
# 1   37i9dQZF1DXc6IFF23C9jj                                   Top Hits of 2010
# 2   37i9dQZF1EMdcXI0FdmrA0                                Your Top Songs 2020
# 3   1B9BPUMWDtl4ASyG4f693s                  Bruno Mars - Official Discography
# 4   37i9dQZF1DWWF3yivn1m3D                                This Is Hans Zimmer
# 5   5acGzAC0OH4QDVj5hlFqlK                                      Study with Me
# 6   37i9dQZF1DX64Y3du11rR1                                         Sad Covers
# 7   37i9dQZF1DXc3FQfFV3K6V                                  Laidback Acoustic
# 8   0vvXsWCC9xrXsKd4FyS8kM       lofi hip hop music - beats to relax/study to
# 9   37i9dQZF1DWWQRwui0ExPn                                        Lo-Fi Beats
# 10  37i9dQZF1DWYfvJNWU1bKi                                      Tamil Romance
# 11  37i9dQZF1DX8DxW4iib3Eq                                This Is John Legend
# 12  37i9dQZF1DX177vQ7mVRmP                                 This Is Bruno Mars
# 13  37i9dQZF1DX1riuLHc7Ui5                             This Is Camila Cabello
# 14  37i9dQZF1DX29brXfjEm5q                                  This Is Sam Smith
# 15  37i9dQZF1DWWxPM4nWdhyI                                 This Is Ed Sheeran
# 16  2QAZ0bGlttwXms2ohJMVe9                                           Melodies
# 17  7jZbNzzf4f0WsYR5v153UZ                         A.R. Rahman – 2.0 enthiran
# 18  11oxVoG1vqvCP6fiqKwXEV                                  Tamil Dance Songs
# 19  3C3GKlgR0uj0dm7jUA4zgW                                      NGHTMRE Radio
# 20  2GrnA8IlKRBKNs8vgRHzGq                                   sad hindi songs
# 21  37i9dQZF1DWYKzhEkKdUkK                                    Bollywood Blast
# 22  1dMyrAIsCdMvqRupu27Bfi                            Lovely Songs <3 | Tamil
# 23  6TIYmDn8GP5tbhtm0xDuRx                      Karthick Iyer Live – Indosoul
# 24  6Hmuuko1DY7cULrpeFeSkd                                     Tamil Melodies
# 25  37i9dQZF1DWXmlLSKkfdAk                                    Acoustic Covers
# 26  74sUjcvpGfdOvCHvgzNEDO  lofi hip hop beats - music to study/relax to |...
# 27  6A3Q5iGA2RvNqzdygcUvmd                     Violin Instrumental Love Songs
# 28  37i9dQZF1DX9sIqqvKsjG8                                 Instrumental Study
# 29  7tWeLQSWPitehz4jTCWtrB                                        Study music
# 30  61pi0dy9neeNT1vwrWIoxL                                              Songs
# 31  1SZ70MXbfW10nDAa07xMFk                                              Tamil
#
#     #tracks
# 0       150
# 1       100
# 2       100
# 3        38
# 4        68
# 5      1030
# 6        61
# 7       101
# 8       309
# 9       450
# 10       98
# 11       57
# 12       43
# 13       35
# 14       49
# 15       41
# 16       47
# 17        5
# 18       92
# 19      154
# 20      240
# 21       40
# 22     1214
# 23        6
# 24      357
# 25      163
# 26      250
# 27       49
# 28      299
# 29       78
# 30       18
# 31      601

# %% [markdown]
# ## Fetch Tracks for each playlists

# %%
def get_playlist_tracks(sp, playlist_id):
    tracks = []
    offset = 0
    while True:
        track_list = sp.playlist_tracks(playlist_id, fields = None, limit = 100, offset = offset, market = None)
        tracks += track_list['items']
        
        if track_list['next'] is not None:
            offset +=100
        else:
            break
            
    track_id = []
    track_name = []
    
    try:
        for track in tracks:
            track_id.append(track['track']['id'])
            track_name.append(track['track']['name'])
    except:
            pass
    
    df_playlist_tracks = pd.DataFrame({'track_id':track_id, 'track_name': track_name})
    return df_playlist_tracks

# %% [markdown]
# ## Get Audio Features for each track within a playlist

# %%
def get_audio_features(sp, playlist_id):
    playlist = get_playlist_tracks(sp, playlist_id)
    audio_features = []
    
    for i in range(len(playlist)):
        try:
            audio_features.append(sp.audio_features(playlist['track_id'][i]))
        except:
            pass
             
             
    feature_list = []
    for feature in audio_features:
        try:
            feature_list.append([feature[0]['danceability'],
                            feature[0]['energy'],
                            feature[0]['key'],
                            feature[0]['loudness'],
                            feature[0]['speechiness'],
                            feature[0]['acousticness'],
                            feature[0]['instrumentalness'],
                            feature[0]['liveness'],
                            feature[0]['valence'],
                            feature[0]['tempo'],
                            feature[0]['duration_ms']]
                               )
        except:
            pass

    df_audio_feature = pd.DataFrame(feature_list, columns = ['danceability', 'energy', 'key', 'loudness', 'speechiness', 
                                                          'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
                                                          'duration_ms'])
    df_playlist_audio_features = pd.concat([playlist, df_audio_feature], axis=1)
    df_playlist_audio_features = df_playlist_audio_features.dropna()
    return df_playlist_audio_features

# %% [markdown]
# ## Get the mean & merge each playlist

# %%
def get_audio_features_mean (sp, playlist_id):
    playlist = get_audio_features(sp, playlist_id)
    df_mean_playlist = pd.DataFrame(playlist.mean(),columns = [playlist_id])
    return df_mean_playlist

# %%
dataframes = []
for i in df_featured_playlists['playlist_id']:
    dataframes.append(get_audio_features_mean(sp, i))
    
dataframes
# Out:
# [                  37i9dQZF1DXbcPC6Vvqudd
#  danceability                    0.143090
#  energy                          0.744021
#  key                             4.313636
#  loudness                      -21.932473
#  speechiness                     0.082850
#  acousticness                    0.226699
#  instrumentalness                0.867155
#  liveness                        0.602012
#  valence                         0.015402
#  tempo                          90.886027
#  duration_ms                184694.836364,
#                    37i9dQZF1DX8Sz1gsYZdwj
#  danceability                    0.300836
#  energy                          0.039274
#  key                             4.638889
#  loudness                      -30.023417
#  speechiness                     0.048289
#  acousticness                    0.970972
#  instrumentalness                0.869444
#  liveness                        0.098786
#  valence                         0.147419
#  tempo                          99.772236
#  duration_ms                212145.805556,
#                    37i9dQZF1DX0QKpU3cGsyb
#  danceability                    0.616493
#  energy                          0.512667
#  key                             5.144928
#  loudness                       -8.115449
#  speechiness                     0.112984
#  acousticness                    0.301822
#  instrumentalness                0.001260
#  liveness                        0.137933
#  valence                         0.414088
#  tempo                         117.355580
#  duration_ms                203294.434783,
#                    37i9dQZF1DWVvXA824aCbn
#  danceability                    0.465843
#  energy                          0.075593
#  key                             4.496063
#  loudness                      -22.019039
#  speechiness                     0.047088
#  acousticness                    0.961614
#  instrumentalness                0.877959
#  liveness                        0.116743
#  valence                         0.145561
#  tempo                          97.694063
#  duration_ms                224274.771654,
#                    37i9dQZF1DWZd79rJ6a7lp
#  danceability                    0.185260
#  energy                          0.038644
#  key                             4.863813
#  loudness                      -30.057572
#  speechiness                     0.041844
#  acousticness                    0.951167
#  instrumentalness                0.886101
#  liveness                        0.106140
#  valence                         0.083682
#  tempo                          84.251650
#  duration_ms                185308.038911,
#                    37i9dQZF1DWX3387IZmjNa
#  danceability                    0.666080
#  energy                          0.573780
#  key                             4.760000
#  loudness                       -7.357560
#  speechiness                     0.206202
#  acousticness                    0.288301
#  instrumentalness                0.000090
#  liveness                        0.175342
#  valence                         0.450644
#  tempo                         108.656200
#  duration_ms                189749.760000,
#                    37i9dQZF1DX4sWSpwq3LiO
#  danceability                    0.381656
#  energy                          0.044988
#  key                             4.785714
#  loudness                      -26.812127
#  speechiness                     0.047706
#  acousticness                    0.991474
#  instrumentalness                0.932815
#  liveness                        0.105537
#  valence                         0.250269
#  tempo                         106.734721
#  duration_ms                151358.110390,
#                    37i9dQZF1DWYcDQ1hSjOpY
#  danceability                    0.158340
#  energy                          0.075285
#  key                             4.713178
#  loudness                      -27.725345
#  speechiness                     0.046178
#  acousticness                    0.893014
#  instrumentalness                0.876034
#  liveness                        0.103958
#  valence                         0.060357
#  tempo                          92.757919
#  duration_ms                207022.096899,
#                    37i9dQZF1DX2UgsUIg75Vg
#  danceability                    0.608220
#  energy                          0.506980
#  key                             5.220000
#  loudness                       -7.814260
#  speechiness                     0.111824
#  acousticness                    0.330442
#  instrumentalness                0.003099
#  liveness                        0.167074
#  valence                         0.398500
#  tempo                         118.533920
#  duration_ms                205067.140000,
#                    37i9dQZF1DXbZmKskFbVct
#  danceability                    0.517643
#  energy                          0.146053
#  key                             5.785714
#  loudness                      -34.809857
#  speechiness                     0.211193
#  acousticness                    0.107698
#  instrumentalness                0.113244
#  liveness                        0.222227
#  valence                         0.098596
#  tempo                          92.285625
#  duration_ms                275205.285714,
#                    37i9dQZF1DWWSads6V2oIk
#  danceability                    0.185529
#  energy                          0.717426
#  key                             5.285714
#  loudness                      -25.071786
#  speechiness                     0.111057
#  acousticness                    0.422009
#  instrumentalness                0.788695
#  liveness                        0.538424
#  valence                         0.033623
#  tempo                          94.894143
#  duration_ms                252936.095238,
#                    37i9dQZF1DWUZ5bk6qqDSy
#  danceability                    0.075192
#  energy                          0.225514
#  key                             4.747475
#  loudness                      -26.061717
#  speechiness                     0.041390
#  acousticness                    0.604397
#  instrumentalness                0.658312
#  liveness                        0.198492
#  valence                         0.017866
#  tempo                          57.318485
#  duration_ms                174383.474747]

# %%
dataframes_user = []
for i in df_user_playlists['playlist_id']:
    dataframes_user.append(get_audio_features_mean(sp, i))
    
dataframes_user
# Out:
# [                  37i9dQZF1DX5Ejj0EkURtP
#  danceability                    0.655820
#  energy                          0.662243
#  key                             5.366667
#  loudness                       -5.620827
#  speechiness                     0.086055
#  acousticness                    0.181648
#  instrumentalness                0.003914
#  liveness                        0.147037
#  valence                         0.490226
#  tempo                         119.850493
#  duration_ms                209190.806667,
#                    37i9dQZF1DXc6IFF23C9jj
#  danceability                    0.641090
#  energy                          0.751320
#  key                             5.260000
#  loudness                       -4.987220
#  speechiness                     0.095363
#  acousticness                    0.116672
#  instrumentalness                0.003646
#  liveness                        0.195073
#  valence                         0.565710
#  tempo                         117.952870
#  duration_ms                226788.920000,
#                    37i9dQZF1EMdcXI0FdmrA0
#  danceability                    0.664510
#  energy                          0.676670
#  key                             5.220000
#  loudness                       -6.566740
#  speechiness                     0.077950
#  acousticness                    0.262011
#  instrumentalness                0.010617
#  liveness                        0.153269
#  valence                         0.545569
#  tempo                         119.529760
#  duration_ms                234229.160000,
#                    1B9BPUMWDtl4ASyG4f693s
#  danceability                    0.694000
#  energy                          0.684921
#  key                             3.815789
#  loudness                       -5.497132
#  speechiness                     0.066234
#  acousticness                    0.176828
#  instrumentalness                0.000310
#  liveness                        0.162055
#  valence                         0.657184
#  tempo                         124.702158
#  duration_ms                217024.842105,
#                    37i9dQZF1DWWF3yivn1m3D
#  danceability                    0.259207
#  energy                          0.265499
#  key                             4.764706
#  loudness                      -18.825971
#  speechiness                     0.046128
#  acousticness                    0.530714
#  instrumentalness                0.784516
#  liveness                        0.136641
#  valence                         0.099951
#  tempo                         108.392926
#  duration_ms                265831.838235,
#                    5acGzAC0OH4QDVj5hlFqlK
#  danceability                    0.251167
#  energy                          0.199991
#  key                             4.955078
#  loudness                      -20.003024
#  speechiness                     0.043549
#  acousticness                    0.726229
#  instrumentalness                0.836103
#  liveness                        0.128580
#  valence                         0.101162
#  tempo                         102.738502
#  duration_ms                204354.043945,
#                    37i9dQZF1DX64Y3du11rR1
#  danceability                    0.543180
#  energy                          0.196211
#  key                             4.868852
#  loudness                      -12.353672
#  speechiness                     0.037708
#  acousticness                    0.852082
#  instrumentalness                0.004356
#  liveness                        0.125195
#  valence                         0.267602
#  tempo                         113.446525
#  duration_ms                206023.590164,
#                    37i9dQZF1DXc3FQfFV3K6V
#  danceability                    0.561455
#  energy                          0.257869
#  key                             5.435644
#  loudness                      -10.971139
#  speechiness                     0.044650
#  acousticness                    0.813079
#  instrumentalness                0.010340
#  liveness                        0.143969
#  valence                         0.359441
#  tempo                         116.026040
#  duration_ms                205601.405941,
#                    0vvXsWCC9xrXsKd4FyS8kM
#  danceability                    0.633019
#  energy                          0.236528
#  key                             5.475728
#  loudness                      -14.754540
#  speechiness                     0.088642
#  acousticness                    0.722039
#  instrumentalness                0.817682
#  liveness                        0.149436
#  valence                         0.248281
#  tempo                         104.126172
#  duration_ms                145672.320388,
#                    37i9dQZF1DWWQRwui0ExPn
#  danceability                    0.678338
#  energy                          0.331056
#  key                             5.355556
#  loudness                      -12.427378
#  speechiness                     0.124382
#  acousticness                    0.614101
#  instrumentalness                0.762774
#  liveness                        0.152775
#  valence                         0.407510
#  tempo                         104.910611
#  duration_ms                129566.042222,
#                    37i9dQZF1DWYfvJNWU1bKi
#  danceability                    0.631071
#  energy                          0.606592
#  key                             5.214286
#  loudness                       -7.434929
#  speechiness                     0.063531
#  acousticness                    0.430233
#  instrumentalness                0.006020
#  liveness                        0.163577
#  valence                         0.527555
#  tempo                         117.651316
#  duration_ms                265807.122449,
#                    37i9dQZF1DX8DxW4iib3Eq
#  danceability                    0.532158
#  energy                          0.606167
#  key                             6.210526
#  loudness                       -6.510368
#  speechiness                     0.100437
#  acousticness                    0.417107
#  instrumentalness                0.001102
#  liveness                        0.189488
#  valence                         0.453737
#  tempo                         107.913947
#  duration_ms                233073.894737,
#                    37i9dQZF1DX177vQ7mVRmP
#  danceability                    0.682070
#  energy                          0.696256
#  key                             3.651163
#  loudness                       -5.356256
#  speechiness                     0.068779
#  acousticness                    0.187541
#  instrumentalness                0.000280
#  liveness                        0.182033
#  valence                         0.633860
#  tempo                         125.028698
#  duration_ms                221480.534884,
#                    37i9dQZF1DX1riuLHc7Ui5
#  danceability                    0.724000
#  energy                          0.491000
#  key                             8.000000
#  loudness                       -6.024000
#  speechiness                     0.029600
#  acousticness                    0.018000
#  instrumentalness                0.000013
#  liveness                        0.088700
#  valence                         0.383000
#  tempo                         105.046000
#  duration_ms                170746.000000,
#                    37i9dQZF1DX29brXfjEm5q
#  danceability                    0.557510
#  energy                          0.443592
#  key                             4.244898
#  loudness                       -8.002776
#  speechiness                     0.065102
#  acousticness                    0.527004
#  instrumentalness                0.005373
#  liveness                        0.151790
#  valence                         0.338531
#  tempo                         116.897184
#  duration_ms                207921.836735,
#                    37i9dQZF1DWWxPM4nWdhyI
#  danceability                    0.687390
#  energy                          0.505659
#  key                             5.609756
#  loudness                       -7.253024
#  speechiness                     0.065346
#  acousticness                    0.416072
#  instrumentalness                0.000144
#  liveness                        0.172559
#  valence                         0.532878
#  tempo                         106.559780
#  duration_ms                236269.024390,
#                    2QAZ0bGlttwXms2ohJMVe9
#  danceability                    0.668149
#  energy                          0.499021
#  key                             5.978723
#  loudness                       -9.312553
#  speechiness                     0.055334
#  acousticness                    0.401739
#  instrumentalness                0.001296
#  liveness                        0.147677
#  valence                         0.535489
#  tempo                         113.400617
#  duration_ms                305778.574468,
#                    7jZbNzzf4f0WsYR5v153UZ
#  danceability                    0.697600
#  energy                          0.650200
#  key                             5.200000
#  loudness                       -8.196000
#  speechiness                     0.047300
#  acousticness                    0.202108
#  instrumentalness                0.014300
#  liveness                        0.126040
#  valence                         0.602600
#  tempo                         123.597600
#  duration_ms                294553.200000,
#                    11oxVoG1vqvCP6fiqKwXEV
#  danceability                    0.725696
#  energy                          0.833109
#  key                             5.760870
#  loudness                       -5.914533
#  speechiness                     0.162557
#  acousticness                    0.314498
#  instrumentalness                0.024128
#  liveness                        0.198957
#  valence                         0.748261
#  tempo                         118.951022
#  duration_ms                269976.869565,
#                    3C3GKlgR0uj0dm7jUA4zgW
#  danceability                    0.610792
#  energy                          0.818714
#  key                             5.370130
#  loudness                       -4.369435
#  speechiness                     0.140615
#  acousticness                    0.076022
#  instrumentalness                0.192526
#  liveness                        0.208232
#  valence                         0.352745
#  tempo                         129.380409
#  duration_ms                206012.857143,
#                    2GrnA8IlKRBKNs8vgRHzGq
#  track_id                             NaN
#  track_name                           NaN
#  danceability                         NaN
#  energy                               NaN
#  key                                  NaN
#  loudness                             NaN
#  speechiness                          NaN
#  acousticness                         NaN
#  instrumentalness                     NaN
#  liveness                             NaN
#  valence                              NaN
#  tempo                                NaN
#  duration_ms                          NaN,
#                    37i9dQZF1DWYKzhEkKdUkK
#  danceability                    0.577800
#  energy                          0.591050
#  key                             5.525000
#  loudness                       -6.835625
#  speechiness                     0.049793
#  acousticness                    0.446235
#  instrumentalness                0.000054
#  liveness                        0.141310
#  valence                         0.420450
#  tempo                         118.404500
#  duration_ms                237879.800000,
#                    1dMyrAIsCdMvqRupu27Bfi
#  danceability                    0.645260
#  energy                          0.576648
#  key                             5.053068
#  loudness                       -8.043822
#  speechiness                     0.057797
#  acousticness                    0.414359
#  instrumentalness                0.012732
#  liveness                        0.146210
#  valence                         0.543604
#  tempo                         118.439920
#  duration_ms                269311.672471,
#                    6TIYmDn8GP5tbhtm0xDuRx
#  danceability                    0.542667
#  energy                          0.523000
#  key                             6.000000
#  loudness                      -12.111167
#  speechiness                     0.055317
#  acousticness                    0.427667
#  instrumentalness                0.736383
#  liveness                        0.118850
#  valence                         0.329650
#  tempo                         117.551167
#  duration_ms                299792.833333,
#                    6Hmuuko1DY7cULrpeFeSkd
#  danceability                    0.558246
#  energy                          0.406340
#  key                             4.845938
#  loudness                      -10.728331
#  speechiness                     0.044462
#  acousticness                    0.582018
#  instrumentalness                0.046264
#  liveness                        0.137164
#  valence                         0.394676
#  tempo                         117.410314
#  duration_ms                268657.431373,
#                    37i9dQZF1DWXmlLSKkfdAk
#  danceability                    0.553337
#  energy                          0.288466
#  key                             5.024540
#  loudness                      -10.936331
#  speechiness                     0.042837
#  acousticness                    0.745220
#  instrumentalness                0.014855
#  liveness                        0.150069
#  valence                         0.339958
#  tempo                         115.993982
#  duration_ms                217547.503067,
#                    74sUjcvpGfdOvCHvgzNEDO
#  danceability                    0.651100
#  energy                          0.292954
#  key                             5.688000
#  loudness                      -13.288876
#  speechiness                     0.108445
#  acousticness                    0.544721
#  instrumentalness                0.769179
#  liveness                        0.146628
#  valence                         0.361004
#  tempo                         111.185436
#  duration_ms                154336.392000,
#                    6A3Q5iGA2RvNqzdygcUvmd
#  danceability                    0.278837
#  energy                          0.342122
#  key                             5.265306
#  loudness                      -12.594980
#  speechiness                     0.032437
#  acousticness                    0.564365
#  instrumentalness                0.755729
#  liveness                        0.153243
#  valence                         0.309059
#  tempo                         114.189551
#  duration_ms                202034.408163,
#                    37i9dQZF1DX9sIqqvKsjG8
#  danceability                    0.368625
#  energy                          0.053097
#  key                             5.227425
#  loudness                      -26.196712
#  speechiness                     0.046009
#  acousticness                    0.990839
#  instrumentalness                0.923629
#  liveness                        0.107383
#  valence                         0.246907
#  tempo                         121.729341
#  duration_ms                148835.515050,
#                    7tWeLQSWPitehz4jTCWtrB
#  danceability                    0.353136
#  energy                          0.130256
#  key                             4.615385
#  loudness                      -20.196718
#  speechiness                     0.054914
#  acousticness                    0.870842
#  instrumentalness                0.884042
#  liveness                        0.120472
#  valence                         0.166490
#  tempo                         105.345218
#  duration_ms                196737.717949,
#                    61pi0dy9neeNT1vwrWIoxL
#  danceability                    0.677889
#  energy                          0.685144
#  key                             4.500000
#  loudness                       -7.264111
#  speechiness                     0.195794
#  acousticness                    0.275822
#  instrumentalness                0.052792
#  liveness                        0.128772
#  valence                         0.596389
#  tempo                         115.543167
#  duration_ms                191520.333333,
#                    1SZ70MXbfW10nDAa07xMFk
#  danceability                    0.661772
#  energy                          0.644173
#  key                             5.219634
#  loudness                       -7.564875
#  speechiness                     0.087321
#  acousticness                    0.354046
#  instrumentalness                0.010093
#  liveness                        0.164132
#  valence                         0.578980
#  tempo                         117.739065
#  duration_ms                280448.337770]

# %%
X = reduce(lambda left,right: pd.merge(left,right, left_index=True, right_index=True), dataframes)
X = X[:10]
X = X.drop('instrumentalness', axis=0)
X
# Out:
#               37i9dQZF1DXbcPC6Vvqudd  37i9dQZF1DX8Sz1gsYZdwj  \
# danceability                0.143090                0.300836
# energy                      0.744021                0.039274
# key                         4.313636                4.638889
# loudness                  -21.932473              -30.023417
# speechiness                 0.082850                0.048289
# acousticness                0.226699                0.970972
# liveness                    0.602012                0.098786
# valence                     0.015402                0.147419
# tempo                      90.886027               99.772236
#
#               37i9dQZF1DX0QKpU3cGsyb  37i9dQZF1DWVvXA824aCbn  \
# danceability                0.616493                0.465843
# energy                      0.512667                0.075593
# key                         5.144928                4.496063
# loudness                   -8.115449              -22.019039
# speechiness                 0.112984                0.047088
# acousticness                0.301822                0.961614
# liveness                    0.137933                0.116743
# valence                     0.414088                0.145561
# tempo                     117.355580               97.694063
#
#               37i9dQZF1DWZd79rJ6a7lp  37i9dQZF1DWX3387IZmjNa  \
# danceability                0.185260                0.666080
# energy                      0.038644                0.573780
# key                         4.863813                4.760000
# loudness                  -30.057572               -7.357560
# speechiness                 0.041844                0.206202
# acousticness                0.951167                0.288301
# liveness                    0.106140                0.175342
# valence                     0.083682                0.450644
# tempo                      84.251650              108.656200
#
#               37i9dQZF1DX4sWSpwq3LiO  37i9dQZF1DWYcDQ1hSjOpY  \
# danceability                0.381656                0.158340
# energy                      0.044988                0.075285
# key                         4.785714                4.713178
# loudness                  -26.812127              -27.725345
# speechiness                 0.047706                0.046178
# acousticness                0.991474                0.893014
# liveness                    0.105537                0.103958
# valence                     0.250269                0.060357
# tempo                     106.734721               92.757919
#
#               37i9dQZF1DX2UgsUIg75Vg  37i9dQZF1DXbZmKskFbVct  \
# danceability                0.608220                0.517643
# energy                      0.506980                0.146053
# key                         5.220000                5.785714
# loudness                   -7.814260              -34.809857
# speechiness                 0.111824                0.211193
# acousticness                0.330442                0.107698
# liveness                    0.167074                0.222227
# valence                     0.398500                0.098596
# tempo                     118.533920               92.285625
#
#               37i9dQZF1DWWSads6V2oIk  37i9dQZF1DWUZ5bk6qqDSy
# danceability                0.185529                0.075192
# energy                      0.717426                0.225514
# key                         5.285714                4.747475
# loudness                  -25.071786              -26.061717
# speechiness                 0.111057                0.041390
# acousticness                0.422009                0.604397
# liveness                    0.538424                0.198492
# valence                     0.033623                0.017866
# tempo                      94.894143               57.318485

# %%
X_2 = reduce(lambda left,right: pd.merge(left,right, left_index=True, right_index=True), dataframes_user)
X_2 = X_2[:10]
X_2
# Out:
#                   37i9dQZF1DX5Ejj0EkURtP  37i9dQZF1DXc6IFF23C9jj  \
# danceability                    0.655820                0.641090
# energy                          0.662243                0.751320
# key                             5.366667                5.260000
# loudness                       -5.620827               -4.987220
# speechiness                     0.086055                0.095363
# acousticness                    0.181648                0.116672
# instrumentalness                0.003914                0.003646
# liveness                        0.147037                0.195073
# valence                         0.490226                0.565710
# tempo                         119.850493              117.952870
#
#                   37i9dQZF1EMdcXI0FdmrA0  1B9BPUMWDtl4ASyG4f693s  \
# danceability                    0.664510                0.694000
# energy                          0.676670                0.684921
# key                             5.220000                3.815789
# loudness                       -6.566740               -5.497132
# speechiness                     0.077950                0.066234
# acousticness                    0.262011                0.176828
# instrumentalness                0.010617                0.000310
# liveness                        0.153269                0.162055
# valence                         0.545569                0.657184
# tempo                         119.529760              124.702158
#
#                   37i9dQZF1DWWF3yivn1m3D  5acGzAC0OH4QDVj5hlFqlK  \
# danceability                    0.259207                0.251167
# energy                          0.265499                0.199991
# key                             4.764706                4.955078
# loudness                      -18.825971              -20.003024
# speechiness                     0.046128                0.043549
# acousticness                    0.530714                0.726229
# instrumentalness                0.784516                0.836103
# liveness                        0.136641                0.128580
# valence                         0.099951                0.101162
# tempo                         108.392926              102.738502
#
#                   37i9dQZF1DX64Y3du11rR1  37i9dQZF1DXc3FQfFV3K6V  \
# danceability                    0.543180                0.561455
# energy                          0.196211                0.257869
# key                             4.868852                5.435644
# loudness                      -12.353672              -10.971139
# speechiness                     0.037708                0.044650
# acousticness                    0.852082                0.813079
# instrumentalness                0.004356                0.010340
# liveness                        0.125195                0.143969
# valence                         0.267602                0.359441
# tempo                         113.446525              116.026040
#
#                   0vvXsWCC9xrXsKd4FyS8kM  37i9dQZF1DWWQRwui0ExPn  ...  \
# danceability                    0.633019                0.678338  ...
# energy                          0.236528                0.331056  ...
# key                             5.475728                5.355556  ...
# loudness                      -14.754540              -12.427378  ...
# speechiness                     0.088642                0.124382  ...
# acousticness                    0.722039                0.614101  ...
# instrumentalness                0.817682                0.762774  ...
# liveness                        0.149436                0.152775  ...
# valence                         0.248281                0.407510  ...
# tempo                         104.126172              104.910611  ...
#
#                   1dMyrAIsCdMvqRupu27Bfi  6TIYmDn8GP5tbhtm0xDuRx  \
# danceability                    0.645260                0.542667
# energy                          0.576648                0.523000
# key                             5.053068                6.000000
# loudness                       -8.043822              -12.111167
# speechiness                     0.057797                0.055317
# acousticness                    0.414359                0.427667
# instrumentalness                0.012732                0.736383
# liveness                        0.146210                0.118850
# valence                         0.543604                0.329650
# tempo                         118.439920              117.551167
#
#                   6Hmuuko1DY7cULrpeFeSkd  37i9dQZF1DWXmlLSKkfdAk  \
# danceability                    0.558246                0.553337
# energy                          0.406340                0.288466
# key                             4.845938                5.024540
# loudness                      -10.728331              -10.936331
# speechiness                     0.044462                0.042837
# acousticness                    0.582018                0.745220
# instrumentalness                0.046264                0.014855
# liveness                        0.137164                0.150069
# valence                         0.394676                0.339958
# tempo                         117.410314              115.993982
#
#                   74sUjcvpGfdOvCHvgzNEDO  6A3Q5iGA2RvNqzdygcUvmd  \
# danceability                    0.651100                0.278837
# energy                          0.292954                0.342122
# key                             5.688000                5.265306
# loudness                      -13.288876              -12.594980
# speechiness                     0.108445                0.032437
# acousticness                    0.544721                0.564365
# instrumentalness                0.769179                0.755729
# liveness                        0.146628                0.153243
# valence                         0.361004                0.309059
# tempo                         111.185436              114.189551
#
#                   37i9dQZF1DX9sIqqvKsjG8  7tWeLQSWPitehz4jTCWtrB  \
# danceability                    0.368625                0.353136
# energy                          0.053097                0.130256
# key                             5.227425                4.615385
# loudness                      -26.196712              -20.196718
# speechiness                     0.046009                0.054914
# acousticness                    0.990839                0.870842
# instrumentalness                0.923629                0.884042
# liveness                        0.107383                0.120472
# valence                         0.246907                0.166490
# tempo                         121.729341              105.345218
#
#                   61pi0dy9neeNT1vwrWIoxL  1SZ70MXbfW10nDAa07xMFk
# danceability                    0.677889                0.661772
# energy                          0.685144                0.644173
# key                             4.500000                5.219634
# loudness                       -7.264111               -7.564875
# speechiness                     0.195794                0.087321
# acousticness                    0.275822                0.354046
# instrumentalness                0.052792                0.010093
# liveness                        0.128772                0.164132
# valence                         0.596389                0.578980
# tempo                         115.543167              117.739065
#
# [10 rows x 32 columns]

# %%
y = pd.DataFrame(df_final_features.mean(), columns = ['top_playlist'])
y = y[:10]
y = y.drop('instrumentalness', axis=0)
y
# Out:
#               top_playlist
# danceability      0.616975
# energy            0.578675
# key               3.625000
# loudness         -7.408175
# speechiness       0.055445
# acousticness      0.300379
# liveness          0.135810
# valence           0.476740
# tempo           118.177050

# %% [markdown]
# ## Memory Based Collaborative Filter

# %% [markdown]
# ### Euclidean Distance - Featured

# %%
#Euclidian distance takes the magnitude of each element within the vector into consideration 
def euclidean_distance(user_playlist,featured_playlist):    
    x = np.sqrt(np.sum((user_playlist - featured_playlist) ** 2))
    return x

# %%
def euc_dataframe(user_playlist):
    featured = []
    distance_score = []
    for i in df_featured_playlists['playlist_id']:
        featured.append(i)
        distance_score.append(euclidean_distance(user_playlist,X[i]))
    df_euc_dist = pd.DataFrame({'featured_playlist':featured, 'distance_score':distance_score})
    sort_values = df_euc_dist.sort_values('distance_score', ascending = True)
    return sort_values

# %%
feat_dist = euc_dataframe(y['top_playlist'])
feat_top_3 = feat_dist.nsmallest(3,'distance_score')
feat_top_3
# Out:
#         featured_playlist  distance_score
# 8  37i9dQZF1DX2UgsUIg75Vg        1.688989
# 2  37i9dQZF1DX0QKpU3cGsyb        1.869981
# 5  37i9dQZF1DWX3387IZmjNa        9.589834

# %% [markdown]
# ### Euclidean Distance - User

# %%
def euc_dataframe(user_playlist):
    featured = []
    distance_score = []
    for i in df_user_playlists['playlist_id']:
        featured.append(i)
        distance_score.append(euclidean_distance(user_playlist,X_2[i]))
    df_euc_dist = pd.DataFrame({'featured_playlist':featured, 'distance_score':distance_score})
    sort_values = df_euc_dist.sort_values('distance_score', ascending = True)
    return sort_values

# %%
user_dist = euc_dataframe(y['top_playlist'])
user_dist = user_dist.drop(user_dist[user_dist['distance_score'] == 0.0000000].index)
user_top_3 = user_dist.nsmallest(3,'distance_score')
user_top_3
# Out:
#          featured_playlist  distance_score
# 0   37i9dQZF1DX5Ejj0EkURtP        0.748584
# 2   37i9dQZF1EMdcXI0FdmrA0        1.251459
# 18  11oxVoG1vqvCP6fiqKwXEV        1.676768

# %% [markdown]
# ## Create playlist df

# %% [markdown]
# ### Create df for featured playlists

# %%
for i, playlist in enumerate(feat_top_3['featured_playlist']):
    try:
        string_command = "df_{} = get_audio_features(sp, playlist)".format(playlist)
        print("Create {}".format(string_command))
        exec(string_command)
    except:
        print("playlist with id {} is not valid, skiping ".format(playlist))
        pass
# Out:
# Create df_37i9dQZF1DX2UgsUIg75Vg = get_audio_features(sp, playlist)
# Create df_37i9dQZF1DX0QKpU3cGsyb = get_audio_features(sp, playlist)
# Create df_37i9dQZF1DWX3387IZmjNa = get_audio_features(sp, playlist)

# %%
def df_playlist(top_3):
    frames = []
    for i, playlist in enumerate(feat_top_3['featured_playlist']):
        string_command_2 = 'df_{}'.format(playlist)
#         string_command_2 = pd.Series(string_command_2)
        frames.append(string_command_2)
    return frames

# %%
top_playlists = df_playlist(feat_top_3['featured_playlist'])
top_playlists
# Out:
# ['df_37i9dQZF1DX2UgsUIg75Vg',
#  'df_37i9dQZF1DX0QKpU3cGsyb',
#  'df_37i9dQZF1DWX3387IZmjNa']

# %% [markdown]
# ### Create df for user playlists

# %%
for i, playlist in enumerate(user_top_3['featured_playlist']):
    try:
        string_command = "df_{} = get_audio_features(sp, playlist)".format(playlist)
        print("Create {}".format(string_command))
        exec(string_command)
    except:
        print("playlist with id {} is not valid, skiping ".format(playlist))
        pass
# Out:
# Create df_37i9dQZF1DX5Ejj0EkURtP = get_audio_features(sp, playlist)
# Create df_37i9dQZF1DXc6IFF23C9jj = get_audio_features(sp, playlist)
# Create df_37i9dQZF1EMdcXI0FdmrA0 = get_audio_features(sp, playlist)
# Create df_1B9BPUMWDtl4ASyG4f693s = get_audio_features(sp, playlist)
# Create df_37i9dQZF1DWWF3yivn1m3D = get_audio_features(sp, playlist)
# Create df_5acGzAC0OH4QDVj5hlFqlK = get_audio_features(sp, playlist)
# Create df_37i9dQZF1DX64Y3du11rR1 = get_audio_features(sp, playlist)
# Create df_37i9dQZF1DXc3FQfFV3K6V = get_audio_features(sp, playlist)
# Create df_0vvXsWCC9xrXsKd4FyS8kM = get_audio_features(sp, playlist)
# Create df_37i9dQZF1DWWQRwui0ExPn = get_audio_features(sp, playlist)
# Create df_37i9dQZF1DWYfvJNWU1bKi = get_audio_features(sp, playlist)
# Create df_37i9dQZF1DX8DxW4iib3Eq = get_audio_features(sp, playlist)
# Create df_37i9dQZF1DX177vQ7mVRmP = get_audio_features(sp, playlist)
# Create df_37i9dQZF1DX1riuLHc7Ui5 = get_audio_features(sp, playlist)
# Create df_37i9dQZF1DX29brXfjEm5q = get_audio_features(sp, playlist)
# Create df_37i9dQZF1DWWxPM4nWdhyI = get_audio_features(sp, playlist)
# Create df_2QAZ0bGlttwXms2ohJMVe9 = get_audio_features(sp, playlist)
# Create df_7jZbNzzf4f0WsYR5v153UZ = get_audio_features(sp, playlist)
# Create df_11oxVoG1vqvCP6fiqKwXEV = get_audio_features(sp, playlist)
# Create df_3C3GKlgR0uj0dm7jUA4zgW = get_audio_features(sp, playlist)
# Create df_2GrnA8IlKRBKNs8vgRHzGq = get_audio_features(sp, playlist)
# Create df_37i9dQZF1DWYKzhEkKdUkK = get_audio_features(sp, playlist)
# Create df_1dMyrAIsCdMvqRupu27Bfi = get_audio_features(sp, playlist)
# Create df_6TIYmDn8GP5tbhtm0xDuRx = get_audio_features(sp, playlist)
# Create df_6Hmuuko1DY7cULrpeFeSkd = get_audio_features(sp, playlist)
# Create df_37i9dQZF1DWXmlLSKkfdAk = get_audio_features(sp, playlist)
# Create df_74sUjcvpGfdOvCHvgzNEDO = get_audio_features(sp, playlist)
# Create df_6A3Q5iGA2RvNqzdygcUvmd = get_audio_features(sp, playlist)
# Create df_37i9dQZF1DX9sIqqvKsjG8 = get_audio_features(sp, playlist)
# Create df_7tWeLQSWPitehz4jTCWtrB = get_audio_features(sp, playlist)
# Create df_61pi0dy9neeNT1vwrWIoxL = get_audio_features(sp, playlist)
# Create df_1SZ70MXbfW10nDAa07xMFk = get_audio_features(sp, playlist)

# %% [markdown]
# ## Create Dataframe with top 3 playlists

# %% [markdown]
# ### Featured Dataframe

# %%
frames_featured = [df_37i9dQZF1DX2UgsUIg75Vg,df_37i9dQZF1DX0QKpU3cGsyb,df_37i9dQZF1DWX3387IZmjNa]
df =pd.concat(frames_featured)
df = df.set_index(['track_id'])
del df['track_name']
del df['duration_ms']
del df['instrumentalness']
df
# Out:
#                         danceability  energy  key  loudness  speechiness  \
# track_id
# 5DNa1gmm4SVyAjAFGmUrTd         0.402   0.369    4    -9.166       0.0851
# 6UF1vUIoLleFrhcxg2L26V         0.566   0.693   10    -6.917       0.3680
# 2uddLj27GIDBIdwRuIomE4         0.746   0.454    9    -8.790       0.0583
# 72rJE1F8Gy2V07SaWG9ZWV         0.525   0.240    5    -7.568       0.0267
# 08HPWLi0YmRUStJzkQ1ffh         0.599   0.449    7    -7.423       0.0529
# ...                              ...     ...  ...       ...          ...
# 6hhHBi9xrYwjtQK1T4mYD0         0.762   0.737    5    -5.290       0.2970
# 5KhWSvBNRGxY5I3t0X6f4w         0.644   0.436    2    -6.104       0.2970
# 0WQwSgQD1pajaWeqPWt1KT         0.617   0.724   11    -6.605       0.3300
# 4gKCKkQbtejYebL9Km5cu1         0.636   0.418    4   -10.536       0.0316
# 6Iw6fQVKZi0fWtEQBrTFcP         0.467   0.429    6    -8.689       0.0964
#
#                         acousticness  liveness  valence    tempo
# track_id
# 5DNa1gmm4SVyAjAFGmUrTd        0.1340    0.1110    0.212  174.376
# 6UF1vUIoLleFrhcxg2L26V        0.3610    0.0806    0.838   78.743
# 2uddLj27GIDBIdwRuIomE4        0.1220    0.2960    0.268  121.921
# 72rJE1F8Gy2V07SaWG9ZWV        0.9390    0.1050    0.369   90.147
# 08HPWLi0YmRUStJzkQ1ffh        0.1610    0.1070    0.143  158.000
# ...                              ...       ...      ...      ...
# 6hhHBi9xrYwjtQK1T4mYD0        0.1150    0.1700    0.641   97.942
# 5KhWSvBNRGxY5I3t0X6f4w        0.4150    0.1560    0.342   82.484
# 0WQwSgQD1pajaWeqPWt1KT        0.0813    0.1070    0.537   79.946
# 4gKCKkQbtejYebL9Km5cu1        0.5030    0.1130    0.347   96.132
# 6Iw6fQVKZi0fWtEQBrTFcP        0.8150    0.1770    0.240  148.530
#
# [169 rows x 9 columns]

# %% [markdown]
# ### Calculate Std.Deviation of the top tracks to tracks in top 3 playlists

# %%
df1 = df.subtract(y['top_playlist'], axis ='columns')
df1 = df1 ** 2
df1['std_dev'] = df1.sum(axis=1)
df1['std_dev'].divide(len(df1))
np.sqrt(df1['std_dev'])
df1= df1.drop_duplicates(subset ="std_dev", keep = False)
df1
# Out:
#                         danceability    energy        key   loudness  \
# track_id
# 5DNa1gmm4SVyAjAFGmUrTd  4.621425e-02  0.043964   0.140625   3.089949
# 6UF1vUIoLleFrhcxg2L26V  2.598451e-03  0.013070  40.640625   0.241253
# 72rJE1F8Gy2V07SaWG9ZWV  8.459401e-03  0.114701   1.890625   0.025544
# 7JeCUUnOpoz4JoV84fliOc  2.130870e-02  0.002989   5.640625   2.748384
# 5A3aEJL7HkijkxLFXMv7FN  2.598451e-03  0.049140  40.640625  12.417343
# ...                              ...       ...        ...        ...
# 6hhHBi9xrYwjtQK1T4mYD0  2.103225e-02  0.025067   1.890625   4.486665
# 5KhWSvBNRGxY5I3t0X6f4w  7.303506e-04  0.020356   2.640625   1.700872
# 0WQwSgQD1pajaWeqPWt1KT  6.250000e-10  0.021119  54.390625   0.645090
# 4gKCKkQbtejYebL9Km5cu1  3.619506e-04  0.025816   0.140625   9.783289
# 6Iw6fQVKZi0fWtEQBrTFcP  2.249250e-02  0.022403   5.640625   1.640513
#
#                         speechiness  acousticness  liveness   valence  \
# track_id
# 5DNa1gmm4SVyAjAFGmUrTd     0.000879      0.027682  0.000616  0.070087
# 6UF1vUIoLleFrhcxg2L26V     0.097691      0.003675  0.003048  0.130509
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-99-eaa5d56f0c4c> in <module>
# ----> 1 frames_user = [df_37i9dQZF1DX5Ejj0EkURtP, df_37i9dQZF1EMdcXI0FdmrA0, df_11oxVoG1vqvCP6fiqKwXEV]
#       2 frames_user
#       3 df_user =pd.concat(frames_user)
#       4 df_user = df_user.set_index(['track_id'])
#       5 del df_user['track_name']
#
# NameError: name 'df_37i9dQZF1DX5Ejj0EkURtP' is not defined

# %% [markdown]
# ### Calculate Std.Deviation of the top tracks to tracks in top 3 playlists

# %%
df_user1 = df_user.subtract(y['top_playlist'], axis ='columns')
df_user1 = df_user1 ** 2
df_user1['std_dev'] = df_user1.sum(axis=1)
df_user1['std_dev'].divide(len(df_user1))
np.sqrt(df_user1['std_dev'])
df_user1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-7b49dbbc0f7f> in <module>
# ----> 1 df_user1 = df_user.subtract(y['top_playlist'], axis ='columns')
#       2 df_user1 = df_user1 ** 2
#       3 df_user1['std_dev'] = df_user1.sum(axis=1)
#       4 df_user1['std_dev'].divide(len(df_user1))
#       5 np.sqrt(df_user1['std_dev'])
#
# NameError: name 'df_user' is not defined

# %%
df_user2 = df_user1.sort_values('variance', ascending = True).head(50)
df_user2
# Out:
#                         danceability    energy    key   loudness  speechiness  \
# track_id
# 5v7gCLVyLgpO5L6zdeXULd  3.878536e-02  0.006072   0.04   1.560800     0.000288
# 5GUM2uDH9Ey4aSvKz1lIdG  4.217204e-03  0.035314   0.04   1.843295     0.006215
# 0MU3DZ68Y09aNseo2e8JJJ  2.990824e-02  0.014622   1.44   1.668437     0.000890
# 2FbaDGEi0rA1AB3bieJKuk  4.925736e-02  0.000098   3.24   0.214999     0.001820
# 3rVBZoeJT4lIr1S9EeENtc  5.467124e-03  0.018747   1.44   0.060359     0.004104
# 2iUXsYOEPhVqEBwsqP70rE  5.634004e-03  0.009984   3.24   0.495166     0.127331
# 39IsH7B5byx8NRlEKlZVg9  1.020164e-03  0.012978   3.24   1.337909     0.005939
# 4nVBt6MZDDP6tRVdQTgxJg  5.049524e-03  0.008296   4.84   0.000246     0.003418
# 4lYKuF88iTBrppJoq03ujE  7.045924e-03  0.001438   1.44   4.497284     0.000599
# 0WdbnNKO0Jt4BZACSDQh44  5.731236e-04  0.000733   0.64   0.208228     0.005456
# 2gqapLp6Br7jcR1QQNBVFz  4.243600e-06  0.021928   0.64  12.015374     0.004003
# 3DmW6y7wTEYHJZlLo1r6XJ  7.806436e-04  0.050661  10.24   2.994007     0.003302
# 6XT0HcEyNMV2w8KgzlWiyp  4.769284e-03  0.008479   0.04   8.639602     0.002584
# 79cuOz3SPQTuFrp8WgftAu  3.457368e-02  0.002109  10.24   3.177948     0.002291
# 0j2WBxWZnWti5TpSxjJvPb  3.357044e-03  0.043297   3.24  12.161401     0.006032
# 3y3brCCecHC3Db18aIOnny  6.409604e-03  0.002409  14.44   0.491850     0.000738
# 2qT1uLXPVPzGgFOx4jtEuo  7.806436e-04  0.001688  14.44   0.096522     0.002187
# 6g1NlCpW7fgqDnWbCCDrHl  12.674597  23.009715
# 4YIhJmihoXwjtbY4vsV9Nh   6.609321  23.944134
# 4ofwffwvvnbSkrMSCKQDaC  22.837503  24.071498
# 3SvKIZDV1zurOUphVI7uWR  19.599569  24.173692
# 1CUVN2kn7mW5FjkqXTR2W1   6.420446  24.360519
# 6LsAAHotRLMOHfCsSfYCsz  11.499830  24.497716
# 6LsAAHotRLMOHfCsSfYCsz  11.499830  24.497716
# 6v3KW9xbzN5yKLt9YKDYA2  12.622814  27.235681
# 0TK2YIli7K1leLovkQiNik  12.765329  27.375337
# 0TK2YIli7K1leLovkQiNik  12.765329  27.375337
# 0JX7Es2j556FwtR6YqMKzP   0.195240  27.689270
# 3Ss0h6wRTuYwnIPXOYa9bs  12.695967  29.124624
# 7xoUc6faLbCqZO6fQEYprd  20.305298  29.134010
# 7nAJz8lfy2wtkPOBROSATs  29.323741  30.415688
# 22kRCQPyNXWZSQEcDvCmGD  12.125299  31.326308
# 049rbQFWg5J85XAhtWTzL8  20.125452  31.841254
# 5fX2oPyLCe5mBKqGDbOWqC  28.549145  32.068919
# 7ef4DlsgrMEH11cDZd32M6  12.069649  33.241600
# 1pwo8l3Ko7idwaz4LVUEC4  30.185574  33.397204
# 72gv4zhNvRVdQA0eOenCal   5.934778  33.522996
# 1x5sYLZiu9r5E43kMlt9f8   5.490305  34.127296
# 09sq0BHe85uV2ADUx1gaiA  29.747643  34.176741
# 2ekn2ttSfGqwhhate0LSR0  19.774564  34.329865
# 0b4C8AiF7eVbZCNGFrx1rv   6.185865  34.366751
# 28veUNu4veN0LOBVa0nFw8   0.277581  34.650470
# 5KawlOMHjWeUjQtnuRs22c   0.279693  35.097926
# 1DFD5Fotzgn6yYXkYsKiGs  12.674597  36.755563
# 6BGQhFWAk9B4fgyDQtHnDL  30.402652  37.975218
# 02GjIfCpwttPAikjm5Hwcb  30.659919  38.028901

# %% [markdown]
# ## Create Discover Playlist

# %%
def create_playlist (sp, username, playlist_name, playlist_description):
    playlists = sp.user_playlist_create(username, playlist_name, description = playlist_description)
    return playlists

# %%
today = str(date.today())
playlist_name = 'Discover Playlist ' + today
disc_pl = create_playlist(sp,username, playlist_name, 'Data Based Discover Playlist Created')
disc_code = disc_pl['uri']
disc_link = disc_code.partition("playlist:")[2]

# %%
def custom_playlist(sp, username, playlist_id, playlist_tracks):
    results = []
    results += sp.user_playlist_add_tracks(username, playlist_id, tracks = playlist_tracks[0:50])

# %%
disc_tracklist = df2.index
custom_playlist (sp, username, disc_link , disc_tracklist)

# %% [markdown]
# ## Create Custom Playlist

# %%
today = str(date.today())
playlist_name2 = 'Custom Playlist ' + today
custom_pl = create_playlist(sp,username, playlist_name2, 'Data Based Custom Playlist Created')
custom_code = custom_pl['uri']
custom_link = custom_code.partition("playlist:")[2]

# %%
def custom_playlist(sp, username, playlist_id, playlist_tracks):
    results = []
    results += sp.user_playlist_add_tracks(username, playlist_id, tracks = playlist_tracks[0:50])

# %%
cust_tracklist = df_user2.index
custom_playlist (sp, username, custom_link , cust_tracklist)
