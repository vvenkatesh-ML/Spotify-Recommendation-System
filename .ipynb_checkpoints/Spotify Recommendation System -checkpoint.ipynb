# %%
import spotipy
import spotipy.util as util
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy.oauth2 as oauth2
import pandas as pd
import numpy as np
import json
import matplotlib.pyplot as plt
import seaborn as sns
# %config InlineBackend.figure_format ='retina'
import random
from functools import reduce

# %%
client_id = '83c1f666855f45f89b2216e55c7bf535'
client_secret = '9bfd86b3fd3c43ada84e1f282fb1df35'
redirect_uri='http://localhost:8910/callback'
username = '61d4pmnwnwjt7xz9tj6v3txho'

scope = 'user-top-read'

client_credentials_manager = SpotifyClientCredentials(client_id=client_id, 
                                                      client_secret=client_secret)
                                                      
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

token = util.prompt_for_user_token(username,scope, client_id, client_secret, redirect_uri)

if token:
    sp = spotipy.Spotify(auth=token)
else:
    print("Can't get token for", username)

# %%
results = sp.current_user_top_tracks(limit=50, offset=0,time_range='short_term')

#Convert the results into a dataframe
track_name = []
track_id = []
artist = []
album = []
duration = []
popularity = []
for i, items in enumerate(results['items']):
        track_name.append(items['name'])
        track_id.append(items['id'])
        artist.append(items["artists"][0]["name"])
        duration.append(items["duration_ms"])
        album.append(items["album"]["name"])
        popularity.append(items["popularity"])

# Create the final df   
df_top_tracks = pd.DataFrame({ "track_name": track_name, 
                             "album": album, 
                             "track_id": track_id,
                             "artist": artist, 
                             "duration": duration, 
                             "popularity": popularity})

df_top_tracks
# Out:
#                                         track_name  \
# 0                                    Vaathi Coming
# 1     Ey Inge Paaru (From "Velaiyilla Pattathari")
# 2                                  Feels Like Love
# 3                           Andha Kanna Paathaakaa
# 4                                  All the Cowboys
# 5                          Day One - Original Demo
# 6                                        My Person
# 7                                Thinking out Loud
# 8                                         Comeback
# 9                     Maybe We Will - 2020 Version
# 10                            Polakattum Para Para
# 11       Neeyum Naanum (From "Naanum Rowdy Dhaan")
# 12                                   Pona Pogattum
# 13       Kadhal Kan Kattudhe (From "Kakki Sattai")
# 14  Udhungada Sangu (From "Velaiyilla Pattathari")
# 15                Shake That (From "Kakki Sattai")
# 16   VIP Title Song (From "Velaiyilla Pattathari")
# 17                                     Vaathi Raid
# 18                         Every Girl I Ever Loved
# 19               I'm So cool (From "Kakki Sattai")
# 20                                    Meet The Man
# 21           Thangamey (From "Naanum Rowdy Dhaan")
# 22     Varavaa Varavaa (From "Naanum Rowdy Dhaan")
# 23                                    Quit Pannuda
# 24                  Hello Beautiful - 2020 Version
# 25                                         Shallow
# 26                   Beat of Master - Instrumental
# 27                       Chellamma (From "Doctor")
# 28                                  Balam Pichkari
# 29               Putham Pudhu Kaalai - Title Track
# 30                                   Nagada Nagada
# 31              Tum Hi Ho Bandhu (From "Cocktail")
# 32                                  Illegal Weapon
# 33                                   Dhadak Dhadak
# 34                                   Kanave Kanave
# 35                            Just the Way You Are
# 36                                        Cutiepie
# 37                                         TiK ToK
# 38                                          Higher
# 39                                     Bad Romance
# 40                                     Take It Off
# 41                                            Mine
# 42                            Love The Way You Lie
# 43                             Talking to the Moon
# 44                                Break Your Heart
# 45                                        Dynamite
# 46                                   Dance Basanti
# 47                  London Thumakda (From "Queen")
# 48                        Feel Again (Feat. Au/Ra)
# 49                                   Bole Chudiyan
#
#                                                 album                track_id  \
# 0         Master (Original Motion Picture Soundtrack)  2BcPFQ7nrtUObgAs72xaac
# 1                                        Voice of Ani  34hssXUwRCru1RbfxCWLth
# 2                                    Noah Schnacky EP  04hHPq6kXTbcSSDrdaP3s4
# 3         Master (Original Motion Picture Soundtrack)  0qvoxfYodIfe14gaidhnsV
# 4                                     All the Cowboys  13TOvHAfdO8wryqxBL7fnI
# 46         Ungli (Original Motion Picture Soundtrack)  1NxlktIRgiAPJ8U06v9veI
# 47                                Best Of Neha Kakkar  1VY2incfH4TLT9PCbot6lj
# 48                        Things I Wanted To Tell You  1fgC2MHbJnPgvDfdTpC62c
# 49  Kabhi Khushi Kabhie Gham (Original Motion Pict...  1uzkWkIaWaxzHJgJ4Fy5rO
#
#                  artist  duration  popularity
# 0   Anirudh Ravichander    228257          63
# 1   Anirudh Ravichander    117788          24
# 2         Noah Schnacky    174760          53
# 3   Anirudh Ravichander    194500          64
# 4         Alexandra Kay    228231          55
# 5           Hans Zimmer    229146          44
# 6      Spencer Crandall    177000          59
# 7            Ed Sheeran    281560          70
# 8         Noah Schnacky    168240          49
# 9         Noah Schnacky    190440          43
# 10  Anirudh Ravichander    214124          54
# 11  Anirudh Ravichander    301951          21
# 12  Anirudh Ravichander     97000          51
# 13  Anirudh Ravichander    256734          22
# 14  Anirudh Ravichander    209640          22
# 15  Anirudh Ravichander    183375          20
# 16  Anirudh Ravichander    236555          21
# 17  Anirudh Ravichander    209500          64
# 18        Noah Schnacky    162891          70
# 19  Anirudh Ravichander    229431          23
# 20        Noah Schnacky    230426          56
# 21  Anirudh Ravichander    262539          23
# 22  Anirudh Ravichander    202378          22
# 23  Anirudh Ravichander    256576          56
# 24        Noah Schnacky    232240          46
# 25    Danielle Bradbery    207746          59
# 26  Anirudh Ravichander     75500          53
# 27  Anirudh Ravichander    236500          70
# 28       Vishal Dadlani    288902          61
# 29        G. V. Prakash    297834          50
# 30           Sonu Nigam    228469          49
# 31      Neeraj Shridhar    282012          53
# 32         Garry Sandhu    230000          63
# 33         Udit Narayan    392411          38
# 34  Anirudh Ravichander    284784          63
# 35           Bruno Mars    220733          82
# 36               Pritam    231562          62
# 37                Kesha    199693          83
# 38        The Saturdays    207613          60
# 39            Lady Gaga    294573          83
# 40                Kesha    215200          71
# 41         Taylor Swift    230706          66
# 42               Eminem    263373          84
# 43           Bruno Mars    217866          79
# 44            Taio Cruz    186266          67
# 45            Taio Cruz    203866          73
# 46         Sachin-Jigar    223991          55
# 47          Labh Janjua    230468          52
# 48                 Kina    139354          65
# 49          Jatin-Lalit    408133          62

# %%
def get_features(sp,df):
    playlist = df[['track_id','track_name']]
    features = []
    
    features += sp.audio_features(playlist.iloc[0:50, 0])

    feature_list = []
    for feature in features:
        feature_list.append([feature['danceability'],
                        feature['energy'],
                        feature['key'],
                        feature['loudness'],
                        feature['mode'],
                        feature['speechiness'],
                        feature['acousticness'],
                        feature['instrumentalness'],
                        feature['liveness'],
                        feature['valence'],
                        feature['tempo'],
                        feature['duration_ms']]
                       )

    df_audio_feature = pd.DataFrame(feature_list, columns = ['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 
                                                          'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
                                                          'duration_ms'])
    df_playlist_audio_features = pd.concat([playlist, df_audio_feature], axis=1)
    return df_playlist_audio_features

# %%
df_final_features = get_features(sp,df_top_tracks)
df_final_features
# Out:
#                   track_id                                      track_name  \
# 0   2BcPFQ7nrtUObgAs72xaac                                   Vaathi Coming
# 1   34hssXUwRCru1RbfxCWLth    Ey Inge Paaru (From "Velaiyilla Pattathari")
# 2   04hHPq6kXTbcSSDrdaP3s4                                 Feels Like Love
# 3   0qvoxfYodIfe14gaidhnsV                          Andha Kanna Paathaakaa
# 4   13TOvHAfdO8wryqxBL7fnI                                 All the Cowboys
# 5   1GelvXCuNRJkSTV8UwAAGw                         Day One - Original Demo
# 6   1MOOJuxUu9QiQE9GgkYYPb                                       My Person
# 7   1Slwb6dOYkBlWal1PGtnNg                               Thinking out Loud
# 8   1wr0HUe5tFDlN32jfwt9IS                                        Comeback
# 9   26LKaGfw6ZolgGArPDEN2R                    Maybe We Will - 2020 Version
# 10  2K058s9yrpoUfANaQt7Zu4                            Polakattum Para Para
# 11  2XMJ3A06ex0UI9JRPeOYrQ       Neeyum Naanum (From "Naanum Rowdy Dhaan")
# 12  2dnAqKYsZRuNVOJ9OVH7Ov                                   Pona Pogattum
# 13  3HTKAcHglpt5HVwJKla9aT       Kadhal Kan Kattudhe (From "Kakki Sattai")
# 14  3K1ee0j1artF9aL9M7cZst  Udhungada Sangu (From "Velaiyilla Pattathari")
# 15  3LSuyxVFp5sLUdZIflhsWs                Shake That (From "Kakki Sattai")
# 16  3rtpnMDvzcE0FRHALqaX3M   VIP Title Song (From "Velaiyilla Pattathari")
# 17  4PML5RtrVcYAwTTS46otXB                                     Vaathi Raid
# 18  4fbnx3oevoht9LNrauDsVP                         Every Girl I Ever Loved
# 19  4kR4T5BFpb6unE1ivbgDfI               I'm So cool (From "Kakki Sattai")
# 20  54iGR32Ba6mRtwLASLkohd                                    Meet The Man
# 21  56bFCJnXMcET6BwVZyJaGO           Thangamey (From "Naanum Rowdy Dhaan")
# 22  5ktYErU0EKwvpen8FDbnaT     Varavaa Varavaa (From "Naanum Rowdy Dhaan")
# 23  66N9OkT3uarJxuzD7iU4BP                                    Quit Pannuda
# 24  6PZR4jQ09UmM9hphbIblQQ                  Hello Beautiful - 2020 Version
# 25  6ysfrXnADdeTtW20oSybln                                         Shallow
# 26  7wQR696XF4L91Zr9groP8v                   Beat of Master - Instrumental
# 27  0fGclndst25Qqy8j4u5De5                       Chellamma (From "Doctor")
# 28  18e3XXYCv4Tx8uUl1mP3CN                                  Balam Pichkari
# 29  2W52SfioS5I4a1DZ734Kuq               Putham Pudhu Kaalai - Title Track
# 30  2W6bC4K4e6y42HnYTA5yHO                                   Nagada Nagada
# 31  2zZTXtLqCsICzEcztKjn47              Tum Hi Ho Bandhu (From "Cocktail")
# 32  3Oe3VdPn6rAueriQvFhCBA                                  Illegal Weapon
# 33  6kOuIhlzgPlqlrWPudpSHL                                   Dhadak Dhadak
# 34  6sPW145Y3LSXd4p1LjBOcS                                   Kanave Kanave
# 35  7BqBn9nzAq8spo5e7cZ0dJ                            Just the Way You Are
# 36  7hXnhouVPnOnFwCGrQMHvB                                        Cutiepie
# 37  0HPD5WQqrq7wPWR7P7Dw1i                                         TiK ToK
# 38  0QVAlchLCx15ZLSoR9Wg1B                                          Higher
# 39  0SiywuOBRcynK0uKGWdCnn                                     Bad Romance
# 40  0WCiI0ddWiu5F2kSHgfw5S                                     Take It Off
# 41  0dBW6ZsW8skfvoRfgeerBF                                            Mine
# 42  15JINEqzVMv3SvJTAXAKED                            Love The Way You Lie
