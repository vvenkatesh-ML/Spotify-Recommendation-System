# %%
import spotipy
import spotipy.util as util
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy.oauth2 as oauth2
import pandas as pd
import numpy as np
import json
import matplotlib.pyplot as plt
import seaborn as sns
# %config InlineBackend.figure_format ='retina'
import random
from functools import reduce

# %% [markdown]
# ## Spotify API Call

# %%
client_id = '83c1f666855f45f89b2216e55c7bf535'
client_secret = '9bfd86b3fd3c43ada84e1f282fb1df35'
redirect_uri='http://localhost:8910/callback'
username = '61d4pmnwnwjt7xz9tj6v3txho'

scope = 'user-top-read'

client_credentials_manager = SpotifyClientCredentials(client_id=client_id, 
                                                      client_secret=client_secret)
                                                      
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

token = util.prompt_for_user_token(username,scope, client_id, client_secret, redirect_uri)

if token:
    sp = spotipy.Spotify(auth=token)
else:
    print("Can't get token for", username)

# %% [markdown]
# ## Top Tracks Extraction

# %%
results = sp.current_user_top_tracks(limit=50, offset=0,time_range='short_term')

#Convert the results into a dataframe
track_name = []
track_id = []
artist = []
album = []
duration = []
popularity = []
for i, items in enumerate(results['items']):
        track_name.append(items['name'])
        track_id.append(items['id'])
        artist.append(items["artists"][0]["name"])
        duration.append(items["duration_ms"])
        album.append(items["album"]["name"])
        popularity.append(items["popularity"])

# Create the final df   
df_top_tracks = pd.DataFrame({ "track_name": track_name, 
                             "album": album, 
                             "track_id": track_id,
                             "artist": artist, 
                             "duration": duration, 
                             "popularity": popularity})

df_top_tracks
# Out:
#                                            track_name  \
# 0                                       Vaathi Coming
# 1        Ey Inge Paaru (From "Velaiyilla Pattathari")
# 2                                     Feels Like Love
# 3                              Andha Kanna Paathaakaa
# 4                                     All the Cowboys
# 5                                           My Person
# 6                                   Thinking out Loud
# 7                                            Comeback
# 8                        Maybe We Will - 2020 Version
# 9                                Polakattum Para Para
# 10          Neeyum Naanum (From "Naanum Rowdy Dhaan")
# 11                                      Pona Pogattum
# 12          Kadhal Kan Kattudhe (From "Kakki Sattai")
# 13     Udhungada Sangu (From "Velaiyilla Pattathari")
# 14                   Shake That (From "Kakki Sattai")
# 15      VIP Title Song (From "Velaiyilla Pattathari")
# 16                                        Vaathi Raid
# 17                            Every Girl I Ever Loved
# 18                  I'm So cool (From "Kakki Sattai")
# 19                                       Meet The Man
# 20              Thangamey (From "Naanum Rowdy Dhaan")
# 21        Varavaa Varavaa (From "Naanum Rowdy Dhaan")
# 22                                       Quit Pannuda
# 23                     Hello Beautiful - 2020 Version
# 24                                            Shallow
# 25                      Beat of Master - Instrumental
# 26                          Chellamma (From "Doctor")
# 27                                     Balam Pichkari
# 28                  Putham Pudhu Kaalai - Title Track
# 29                                      Nagada Nagada
# 30                 Tum Hi Ho Bandhu (From "Cocktail")
# 31                                     Illegal Weapon
# 32                                      Dhadak Dhadak
# 33                                      Kanave Kanave
# 34                                           Cutiepie
# 35                                      Dance Basanti
# 36                     London Thumakda (From "Queen")
# 37                           Feel Again (Feat. Au/Ra)
# 38                                      Bole Chudiyan
# 39                  Dj Waley Babu (feat. Aastha Gill)
# 40                                       Daru Badnaam
# 41             Kaattu Payale (From "Soorarai Pottru")
# 42              Veyyon Silli (From "Soorarai Pottru")
# 43                     Coca Cola (From "Luka Chuppi")
# 44                                          Suit Suit
# 45    Rakita Rakita Rakita (From "Jagame Thandhiram")
# 46  Kar Gayi Chull (From "Kapoor & Sons (Since 192...
# 37                        Things I Wanted To Tell You  1fgC2MHbJnPgvDfdTpC62c
# 38  Kabhi Khushi Kabhie Gham (Original Motion Pict...  1uzkWkIaWaxzHJgJ4Fy5rO
# 39                  Dj Waley Babu (feat. Aastha Gill)  2SRv30X7NoYRZB62dX0UzH
# 40                                       Daru Badnaam  2TzyJEUfWHGRsk3r6Emvbk
# 41             Kaattu Payale (From "Soorarai Pottru")  2b4nWymybHj38A6XtQijiA
# 42              Veyyon Silli (From "Soorarai Pottru")  2gqapLp6Br7jcR1QQNBVFz
# 43                                     Dance Syndrome  2hOlxSH3Zck6a2ki4xtKGV
# 44                              Hits Of Guru Randhawa  2mwBSO58y92EYmEFpDfmS7
# 45    Rakita Rakita Rakita (From "Jagame Thandhiram")  2oNRoniEFnPdaCfkOQ9m0C
# 46  Kar Gayi Chull (From "Kapoor & Sons (Since 192...  3Q8yDujnXxwRiZ4p6VqY7b
# 47       Dostana (Original Motion Picture Soundtrack)  3Qpk2qHree1RTH5lZaKnEK
# 48  Student of the Year (Original Motion Picture S...  3UaP2PQwhA31keZXt7oPLA
# 49                            Yeh Jawaani Hai Deewani  3W1XPf7mvuQcWQB7U7MbTM
#
#                  artist  duration  popularity
# 0   Anirudh Ravichander    228257          63
# 1   Anirudh Ravichander    117788          24
# 2         Noah Schnacky    174760          53
# 3   Anirudh Ravichander    194500          64
# 4         Alexandra Kay    228231          55
# 5      Spencer Crandall    177000          59
# 6            Ed Sheeran    281560          70
# 7         Noah Schnacky    168240          49
# 8         Noah Schnacky    190440          43
# 9   Anirudh Ravichander    214124          55
# 10  Anirudh Ravichander    301951          21
# 11  Anirudh Ravichander     97000          52
# 12  Anirudh Ravichander    256734          22
# 13  Anirudh Ravichander    209640          22
# 14  Anirudh Ravichander    183375          20
# 15  Anirudh Ravichander    236555          22
# 16  Anirudh Ravichander    209500          64
# 17        Noah Schnacky    162891          71
# 18  Anirudh Ravichander    229431          23
# 19        Noah Schnacky    230426          56
# 20  Anirudh Ravichander    262539          23
# 21  Anirudh Ravichander    202378          22
# 22  Anirudh Ravichander    256576          57
# 23        Noah Schnacky    232240          46
# 24    Danielle Bradbery    207746          59
# 25  Anirudh Ravichander     75500          53
# 26  Anirudh Ravichander    236500          70
# 27       Vishal Dadlani    288902          61
# 28        G. V. Prakash    297834          50
# 29           Sonu Nigam    228469          49
# 30      Neeraj Shridhar    282012          53
# 31         Garry Sandhu    230000          63
# 32         Udit Narayan    392411          38
# 33  Anirudh Ravichander    284784          63
# 34               Pritam    231562          62
# 35         Sachin-Jigar    223991          55
# 36          Labh Janjua    230468          52
# 37                 Kina    139354          65
# 38          Jatin-Lalit    408133          62
# 39              Badshah    169080          55
# 40          Param Singh    185333          65
# 41        G. V. Prakash    246000          68
# 42        G. V. Prakash    304000          64
# 43          Tony Kakkar    179225          54
# 44        Guru Randhawa    190131          64
# 45   Santhosh Narayanan    247455          67
# 46              Badshah    187710          52
# 47       Vishal-Shekhar    306986          56
# 48       Vishal-Shekhar    342093          56
# 49         Arijit Singh    260552          58

# %% [markdown]
# ## Features Extraction

# %%
def get_features(sp,df):
    playlist = df[['track_id','track_name']]
    features = []
    
    features += sp.audio_features(playlist.iloc[0:50, 0])

    feature_list = []
    for feature in features:
        feature_list.append([feature['danceability'],
                        feature['energy'],
                        feature['key'],
                        feature['loudness'],
                        feature['mode'],
                        feature['speechiness'],
                        feature['acousticness'],
                        feature['instrumentalness'],
                        feature['liveness'],
                        feature['valence'],
                        feature['tempo'],
                        feature['duration_ms']]
                       )

    df_audio_feature = pd.DataFrame(feature_list, columns = ['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 
                                                          'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
                                                          'duration_ms'])
    df_playlist_audio_features = pd.concat([playlist, df_audio_feature], axis=1)
    return df_playlist_audio_features

# %%
df_final_features = get_features(sp,df_top_tracks)
#Drop the mode feature as it is binary
del df_final_features['mode']
df_final_features
# Out:
#                   track_id                                         track_name  \
# 0   2BcPFQ7nrtUObgAs72xaac                                      Vaathi Coming
# 1   34hssXUwRCru1RbfxCWLth       Ey Inge Paaru (From "Velaiyilla Pattathari")
# 2   04hHPq6kXTbcSSDrdaP3s4                                    Feels Like Love
# 3   0qvoxfYodIfe14gaidhnsV                             Andha Kanna Paathaakaa
# 4   13TOvHAfdO8wryqxBL7fnI                                    All the Cowboys
# 5   1MOOJuxUu9QiQE9GgkYYPb                                          My Person
# 6   1Slwb6dOYkBlWal1PGtnNg                                  Thinking out Loud
# 7   1wr0HUe5tFDlN32jfwt9IS                                           Comeback
# 8   26LKaGfw6ZolgGArPDEN2R                       Maybe We Will - 2020 Version
# 9   2K058s9yrpoUfANaQt7Zu4                               Polakattum Para Para
# 10  2XMJ3A06ex0UI9JRPeOYrQ          Neeyum Naanum (From "Naanum Rowdy Dhaan")
# 11  2dnAqKYsZRuNVOJ9OVH7Ov                                      Pona Pogattum
# 12  3HTKAcHglpt5HVwJKla9aT          Kadhal Kan Kattudhe (From "Kakki Sattai")
# 13  3K1ee0j1artF9aL9M7cZst     Udhungada Sangu (From "Velaiyilla Pattathari")
# 14  3LSuyxVFp5sLUdZIflhsWs                   Shake That (From "Kakki Sattai")
# 15  3rtpnMDvzcE0FRHALqaX3M      VIP Title Song (From "Velaiyilla Pattathari")
# 16  4PML5RtrVcYAwTTS46otXB                                        Vaathi Raid
# 17  4fbnx3oevoht9LNrauDsVP                            Every Girl I Ever Loved
# 18  4kR4T5BFpb6unE1ivbgDfI                  I'm So cool (From "Kakki Sattai")
# 19  54iGR32Ba6mRtwLASLkohd                                       Meet The Man
# 20  56bFCJnXMcET6BwVZyJaGO              Thangamey (From "Naanum Rowdy Dhaan")
# 21  5ktYErU0EKwvpen8FDbnaT        Varavaa Varavaa (From "Naanum Rowdy Dhaan")
# 22  66N9OkT3uarJxuzD7iU4BP                                       Quit Pannuda
# 23  6PZR4jQ09UmM9hphbIblQQ                     Hello Beautiful - 2020 Version
# 24  6ysfrXnADdeTtW20oSybln                                            Shallow
# 25  7wQR696XF4L91Zr9groP8v                      Beat of Master - Instrumental
# 26  0fGclndst25Qqy8j4u5De5                          Chellamma (From "Doctor")
# 27  18e3XXYCv4Tx8uUl1mP3CN                                     Balam Pichkari
# 28  2W52SfioS5I4a1DZ734Kuq                  Putham Pudhu Kaalai - Title Track
# 29  2W6bC4K4e6y42HnYTA5yHO                                      Nagada Nagada
# 30  2zZTXtLqCsICzEcztKjn47                 Tum Hi Ho Bandhu (From "Cocktail")
# 31  3Oe3VdPn6rAueriQvFhCBA                                     Illegal Weapon
# 32  6kOuIhlzgPlqlrWPudpSHL                                      Dhadak Dhadak
# 33  6sPW145Y3LSXd4p1LjBOcS                                      Kanave Kanave
# 34  7hXnhouVPnOnFwCGrQMHvB                                           Cutiepie
# 35  1NxlktIRgiAPJ8U06v9veI                                      Dance Basanti
# 36  1VY2incfH4TLT9PCbot6lj                     London Thumakda (From "Queen")
# 37  1fgC2MHbJnPgvDfdTpC62c                           Feel Again (Feat. Au/Ra)
# 38  1uzkWkIaWaxzHJgJ4Fy5rO                                      Bole Chudiyan
# 39  2SRv30X7NoYRZB62dX0UzH                  Dj Waley Babu (feat. Aastha Gill)
# 40  2TzyJEUfWHGRsk3r6Emvbk                                       Daru Badnaam
# 41  2b4nWymybHj38A6XtQijiA             Kaattu Payale (From "Soorarai Pottru")
# 42  2gqapLp6Br7jcR1QQNBVFz              Veyyon Silli (From "Soorarai Pottru")
# 43  2hOlxSH3Zck6a2ki4xtKGV                     Coca Cola (From "Luka Chuppi")
# 44  2mwBSO58y92EYmEFpDfmS7                                          Suit Suit
# 45  2oNRoniEFnPdaCfkOQ9m0C    Rakita Rakita Rakita (From "Jagame Thandhiram")
# 46  3Q8yDujnXxwRiZ4p6VqY7b  Kar Gayi Chull (From "Kapoor & Sons (Since 192...
# 47  3Qpk2qHree1RTH5lZaKnEK                                          Desi Girl
# 48  3UaP2PQwhA31keZXt7oPLA                                     The Disco Song
# 49  3W1XPf7mvuQcWQB7U7MbTM                              Dilliwaali Girlfriend
#
#     danceability  energy  key  loudness  speechiness  acousticness  \
# 0          0.643   0.952    7    -4.150       0.2460       0.27600
# 1          0.643   0.834    7    -4.104       0.1820       0.06520
# 2          0.639   0.845    2    -5.139       0.0414       0.00117
# 3          0.747   0.860    6    -4.071       0.2790       0.30100
# 4          0.501   0.554    9    -6.292       0.0265       0.32100
# 5          0.567   0.753    7    -5.291       0.0487       0.08940
# 6          0.781   0.445    2    -6.061       0.0295       0.47400
# 7          0.542   0.817   11    -5.192       0.0324       0.03830
# 8          0.685   0.485    4    -7.755       0.0272       0.15100
# 9          0.758   0.796   11    -6.483       0.1700       0.16500
# 10         0.572   0.620    9    -9.949       0.0436       0.10100
# 11         0.685   0.476    0    -9.573       0.0369       0.83000
# 12         0.615   0.537    2    -4.951       0.0295       0.57200
# 13         0.519   0.806    8    -5.552       0.1180       0.21400
# 17          0.000000    0.0964    0.576  189.933       162891
# 18          0.000000    0.1800    0.819   87.600       229432
# 19          0.000002    0.1060    0.593  150.022       230427
# 20          0.000000    0.2430    0.627   99.909       262540
# 21          0.000000    0.0440    0.659  129.989       202379
# 22          0.000000    0.4430    0.499   76.965       256577
# 23          0.000000    0.1820    0.299  148.084       232240
# 24          0.000000    0.0829    0.326   95.989       207747
# 25          0.880000    0.0894    0.547  172.429        75500
# 26          0.000325    0.0589    0.743   99.702       236500
# 27          0.000000    0.4030    0.957  120.019       288903
# 28          0.000025    0.1060    0.314  159.915       297835
# 29          0.007900    0.5070    0.727  120.006       228469
# 30          0.000817    0.0462    0.899  134.997       282012
# 31          0.000042    0.1080    0.714   94.020       230000
# 32          0.000000    0.1100    0.562  113.975       392411
# 33          0.000006    0.1230    0.477   95.015       284784
# 34          0.000462    0.2400    0.952  127.999       231562
# 35          0.000003    0.3630    0.804  103.035       223992
# 36          0.000919    0.0625    0.640  139.968       230468
# 37          0.000000    0.1240    0.224   78.138       139355
# 38          0.000012    0.1640    0.736   96.915       408133
# 39          0.000000    0.1260    0.783  110.000       169080
# 40          0.000000    0.1590    0.845   90.037       185333
# 41          0.000246    0.3760    0.490   78.924       246000
# 42          0.000000    0.3720    0.653  119.998       304000
# 43          0.005200    0.1230    0.893  102.009       179225
# 44          0.000000    0.2210    0.751   98.208       190132
# 45          0.000165    0.5230    0.948  133.526       247455
# 46          0.000322    0.2110    0.873  121.990       187711
# 47          0.002790    0.0970    0.807  136.051       306987
# 48          0.028800    0.1200    0.615  125.006       342093
# 49          0.000003    0.0697    0.909  138.047       260552

# %% [markdown]
# ## EDA Performed

# %% [markdown]
# ## Featured Playlists Extraction

# %%
def featured_playlists(sp):
    id = []
    name = []
    num_tracks = []
    
    featured = sp.featured_playlists()
    playlists = featured['playlists']
    for i, items in enumerate(playlists['items']):
        id.append(items['id'])
        name.append(items['name'])
        num_tracks.append(items['tracks']['total'])
    
    df_playlists = pd.DataFrame({'playlist_id':id, 'playlist_name':name, '#tracks': num_tracks})
    return df_playlists

# %%
df_featured_playlists = featured_playlists(sp)
df_featured_playlists
# Out:
#                playlist_id        playlist_name  #tracks
# 0   37i9dQZF1DWU0ScTcjJBdj       Relax & Unwind      100
# 1   37i9dQZF1DWTwbZHrJRIgD        Happy Weekend       54
# 2   37i9dQZF1DX4pUKG1kS0Ac     Guilty Pleasures      151
# 3   37i9dQZF1DWYAcBZSAVhlf  Walking On Sunshine       80
# 4   37i9dQZF1DWWBHeXOYZf74               POLLEN      183
# 5   37i9dQZF1DX5hkGHr0ICaZ   The Metal Festival       90
# 6   37i9dQZF1DX4o1oenSJRJd          All Out 00s      100
# 7   37i9dQZF1DX4bSrsRWE9cd                Bliss       74
# 8   37i9dQZF1DWZKuerrwoAGz      Happy Favorites      100
# 9   37i9dQZF1DX4VvfRBFClxm        Acoustic Hits      100
# 10  37i9dQZF1DX4MTfCb9IRyO     Summertime Blues       50
# 11  37i9dQZF1DX4dyzvuaRJ0n                 mint       79

# %% [markdown]
# ## Fetch Tracks for each playlists

# %%
def get_playlist_tracks(sp, playlist_id):
    tracks = []
    offset = 0
    while True:
        track_list = sp.playlist_tracks(playlist_id, fields = None, limit = 100, offset = offset, market = None)
        tracks += track_list['items']
        
        if track_list['next'] is not None:
            offset +=100
        else:
            break
            
    track_id = []
    track_name = []
    
    for track in tracks:
        track_id.append(track['track']['id'])
        track_name.append(track['track']['name'])
    
    df_playlist_tracks = pd.DataFrame({'track_id':track_id, 'track_name': track_name})
    return df_playlist_tracks

# %% [markdown]
# ## Get Audio Features for each track within a playlist

# %%
def get_audio_features(sp, playlist_id):
    playlist = get_playlist_tracks(sp, playlist_id)
    audio_features = []
    index = 0
    while index < playlist.shape[0]:
        audio_features += sp.audio_features(playlist.iloc[index:index + 50, 0])
        index += 50
    
    feature_list = []
    for feature in audio_features:
        feature_list.append([feature['danceability'],
                        feature['energy'],
                        feature['key'],
                        feature['loudness'],
#                         feature['mode'],
                        feature['speechiness'],
                        feature['acousticness'],
                        feature['instrumentalness'],
                        feature['liveness'],
                        feature['valence'],
                        feature['tempo'],
                        feature['duration_ms']]
                       )

    df_audio_feature = pd.DataFrame(feature_list, columns = ['danceability', 'energy', 'key', 'loudness', 'speechiness', 
                                                          'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
                                                          'duration_ms'])
    df_playlist_audio_features = pd.concat([playlist, df_audio_feature], axis=1)
    return df_playlist_audio_features

# %% [markdown]
# ## Get the mean & merge each playlist

# %%
def get_audio_features_mean (sp, playlist_id):
    playlist = get_audio_features(sp, playlist_id)
    df_mean_playlist = pd.DataFrame(playlist.mean(),columns = [playlist_id])
    return df_mean_playlist

# %%
dataframes = []
for i in df_featured_playlists['playlist_id']:
    dataframes.append(get_audio_features_mean(sp, i))
    
dataframes
# Out:
# [                  37i9dQZF1DWU0ScTcjJBdj
#  danceability                    0.521310
#  energy                          0.363995
#  key                             5.810000
#  loudness                      -11.082280
#  speechiness                     0.038126
#  acousticness                    0.695853
#  instrumentalness                0.074661
#  liveness                        0.155497
#  valence                         0.297808
#  tempo                         117.174500
#  duration_ms                241161.370000,
#                    37i9dQZF1DWTwbZHrJRIgD
#  danceability                    0.679463
#  energy                          0.687407
#  key                             5.351852
#  loudness                       -7.141241
#  speechiness                     0.062146
#  acousticness                    0.282147
#  instrumentalness                0.028680
#  liveness                        0.161083
#  valence                         0.573424
#  tempo                         118.554074
#  duration_ms                242786.537037,
#                    37i9dQZF1DX4pUKG1kS0Ac
#  danceability                    0.662735
#  energy                          0.732854
#  key                             5.231788
#  loudness                       -6.020570
#  speechiness                     0.078672
#  acousticness                    0.147867
#  instrumentalness                0.019931
#  liveness                        0.167897
#  valence                         0.647991
#  tempo                         120.882874
#  duration_ms                231943.086093,
#                    37i9dQZF1DWYAcBZSAVhlf
#  danceability                    0.716238
#  energy                          0.760475
#  key                             4.925000
#  loudness                       -9.260400
#  speechiness                     0.053849
#  acousticness                    0.173648
#  instrumentalness                0.037458
#  liveness                        0.176471
#  valence                         0.787525
#  tempo                         119.811275
#  duration_ms                243454.550000,
#                    37i9dQZF1DWWBHeXOYZf74
#  danceability                    0.676158
#  energy                          0.575350
#  key                             5.076503
#  loudness                       -8.252749
#  speechiness                     0.117820
#  acousticness                    0.306755
#  instrumentalness                0.148863
#  liveness                        0.184768
#  valence                         0.499392
#  tempo                         116.484989
#  duration_ms                202095.491803,
#                    37i9dQZF1DX5hkGHr0ICaZ
#  danceability                    0.329411
#  energy                          0.926578
#  key                             4.944444
#  loudness                       -6.302944
#  speechiness                     0.111940
#  acousticness                    0.008336
#  instrumentalness                0.184432
#  liveness                        0.778233
#  valence                         0.231883
#  tempo                         116.386889
#  duration_ms                315302.322222,
#                    37i9dQZF1DX4o1oenSJRJd
#  danceability                    0.672330
#  energy                          0.684900
#  key                             5.610000
#  loudness                       -5.913230
#  speechiness                     0.076795
#  acousticness                    0.169791
#  instrumentalness                0.008871
#  liveness                        0.160323
#  valence                         0.579362
#  tempo                         118.321890
#  duration_ms                235897.950000,
#                    37i9dQZF1DX4bSrsRWE9cd
#  danceability                    0.495473
#  energy                          0.235396
#  key                             3.770270
#  loudness                      -14.778986
#  speechiness                     0.038682
#  acousticness                    0.816699
#  instrumentalness                0.164258
#  liveness                        0.133188
#  valence                         0.248828
#  tempo                         117.758108
#  duration_ms                231246.891892,
#                    37i9dQZF1DWZKuerrwoAGz
#  danceability                    0.693280
#  energy                          0.784060
#  key                             5.030000
#  loudness                       -4.707560
#  speechiness                     0.069165
#  acousticness                    0.097232
#  instrumentalness                0.001667
#  liveness                        0.178706
#  valence                         0.634320
#  tempo                         116.592160
#  duration_ms                214889.500000,
#                    37i9dQZF1DX4VvfRBFClxm
#  danceability                    0.573590
#  energy                          0.351716
#  key                             5.530000
#  loudness                       -9.575590
#  speechiness                     0.046322
#  acousticness                    0.675120
#  instrumentalness                0.017179
#  liveness                        0.125548
#  valence                         0.362309
#  tempo                         116.239310
#  duration_ms                216127.240000,
#                    37i9dQZF1DX4MTfCb9IRyO
#  danceability                    0.593440
#  energy                          0.494940
#  key                             5.400000
#  loudness                      -10.999140
#  speechiness                     0.049852
#  acousticness                    0.506314
#  instrumentalness                0.086893
#  liveness                        0.189042
#  valence                         0.741960
#  tempo                         114.266520
#  duration_ms                219416.400000,
#                    37i9dQZF1DX4dyzvuaRJ0n
#  danceability                    0.694823
#  energy                          0.770468
#  key                             5.784810
#  loudness                       -5.858076
#  speechiness                     0.066967
#  acousticness                    0.103999
#  instrumentalness                0.121008
#  liveness                        0.177778
#  valence                         0.442868
#  tempo                         126.806924
#  duration_ms                191994.164557]

# %%
#Combines the 
X = reduce(lambda left,right: pd.merge(left,right, left_index=True, right_index=True), dataframes)
X
# Out:
#                   37i9dQZF1DWU0ScTcjJBdj  37i9dQZF1DWTwbZHrJRIgD  \
# danceability                    0.521310                0.679463
# energy                          0.363995                0.687407
# key                             5.810000                5.351852
# loudness                      -11.082280               -7.141241
# speechiness                     0.038126                0.062146
# acousticness                    0.695853                0.282147
# instrumentalness                0.074661                0.028680
# liveness                        0.155497                0.161083
# valence                         0.297808                0.573424
# tempo                         117.174500              118.554074
# duration_ms                241161.370000           242786.537037
#
#                   37i9dQZF1DX4pUKG1kS0Ac  37i9dQZF1DWYAcBZSAVhlf  \
# danceability                    0.662735                0.716238
# energy                          0.732854                0.760475
# key                             5.231788                4.925000
# loudness                       -6.020570               -9.260400
# speechiness                     0.078672                0.053849
# acousticness                    0.147867                0.173648
# instrumentalness                0.019931                0.037458
# liveness                        0.167897                0.176471
# valence                         0.647991                0.787525
# tempo                         120.882874              119.811275
# duration_ms                231943.086093           243454.550000
#
#                   37i9dQZF1DWWBHeXOYZf74  37i9dQZF1DX5hkGHr0ICaZ  \
# danceability                    0.676158                0.329411
# energy                          0.575350                0.926578
# key                             5.076503                4.944444
# loudness                       -8.252749               -6.302944
# speechiness                     0.117820                0.111940
# acousticness                    0.306755                0.008336
# instrumentalness                0.148863                0.184432
# liveness                        0.184768                0.778233
# valence                         0.499392                0.231883
# tempo                         116.484989              116.386889
# duration_ms                202095.491803           315302.322222
#
#                   37i9dQZF1DX4o1oenSJRJd  37i9dQZF1DX4bSrsRWE9cd  \
# danceability                    0.672330                0.495473
# energy                          0.684900                0.235396
# key                             5.610000                3.770270
# loudness                       -5.913230              -14.778986
# speechiness                     0.076795                0.038682
# acousticness                    0.169791                0.816699
# instrumentalness                0.008871                0.164258
# liveness                        0.160323                0.133188
# valence                         0.579362                0.248828
# tempo                         118.321890              117.758108
# duration_ms                235897.950000           231246.891892
#
#                   37i9dQZF1DWZKuerrwoAGz  37i9dQZF1DX4VvfRBFClxm  \
# danceability                    0.693280                0.573590
# energy                          0.784060                0.351716
# key                             5.030000                5.530000
# loudness                       -4.707560               -9.575590
# speechiness                     0.069165                0.046322
# acousticness                    0.097232                0.675120
# instrumentalness                0.001667                0.017179
# liveness                        0.178706                0.125548
# valence                         0.634320                0.362309
# tempo                         116.592160              116.239310
# duration_ms                214889.500000           216127.240000
#
#                   37i9dQZF1DX4MTfCb9IRyO  37i9dQZF1DX4dyzvuaRJ0n
# danceability                    0.593440                0.694823
# energy                          0.494940                0.770468
# key                             5.400000                5.784810
# loudness                      -10.999140               -5.858076
# speechiness                     0.049852                0.066967
# acousticness                    0.506314                0.103999
# instrumentalness                0.086893                0.121008
# liveness                        0.189042                0.177778
# valence                         0.741960                0.442868
# tempo                         114.266520              126.806924
# duration_ms                219416.400000           191994.164557

# %%
y = pd.DataFrame(df_final_features.mean(), columns = ['top_playlist'])
y
# Out:
#                    top_playlist
# danceability           0.671260
# energy                 0.750880
# key                    5.300000
# loudness              -5.966620
# speechiness            0.100022
# acousticness           0.240452
# instrumentalness       0.034367
# liveness               0.198582
# valence                0.667400
# tempo                121.361960
# duration_ms       228447.680000
