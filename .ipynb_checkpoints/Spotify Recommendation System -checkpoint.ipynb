# %%
import spotipy
import spotipy.util as util
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy.oauth2 as oauth2
import pandas as pd
import numpy as np
import json
import matplotlib.pyplot as plt
import seaborn as sns
# %config InlineBackend.figure_format ='retina'
import random
from functools import reduce

# %% [markdown]
# ## Spotify API Call

# %%
client_id = '83c1f666855f45f89b2216e55c7bf535'
client_secret = '9bfd86b3fd3c43ada84e1f282fb1df35'
redirect_uri='http://localhost:8910/callback'
username = '61d4pmnwnwjt7xz9tj6v3txho'

scope = 'user-top-read'

client_credentials_manager = SpotifyClientCredentials(client_id=client_id, 
                                                      client_secret=client_secret)
                                                      
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

token = util.prompt_for_user_token(username,scope, client_id, client_secret, redirect_uri)

if token:
    sp = spotipy.Spotify(auth=token)
else:
    print("Can't get token for", username)

# %% [markdown]
# ## Top Tracks Extraction

# %%
results = sp.current_user_top_tracks(limit=50, offset=0,time_range='short_term')

#Convert the results into a dataframe
track_name = []
track_id = []
artist = []
album = []
duration = []
popularity = []
for i, items in enumerate(results['items']):
        track_name.append(items['name'])
        track_id.append(items['id'])
        artist.append(items["artists"][0]["name"])
        duration.append(items["duration_ms"])
        album.append(items["album"]["name"])
        popularity.append(items["popularity"])

# Create the final df   
df_top_tracks = pd.DataFrame({ "track_name": track_name, 
                             "album": album, 
                             "track_id": track_id,
                             "artist": artist, 
                             "duration": duration, 
                             "popularity": popularity})

df_top_tracks
# Out:
#                                            track_name  \
# 0                                       Vaathi Coming
# 1        Ey Inge Paaru (From "Velaiyilla Pattathari")
# 2                                     Feels Like Love
# 3                              Andha Kanna Paathaakaa
# 4                                     All the Cowboys
# 5                                           My Person
# 6                                            Comeback
# 7                        Maybe We Will - 2020 Version
# 8                                Polakattum Para Para
# 9           Neeyum Naanum (From "Naanum Rowdy Dhaan")
# 10                                      Pona Pogattum
# 11          Kadhal Kan Kattudhe (From "Kakki Sattai")
# 12     Udhungada Sangu (From "Velaiyilla Pattathari")
# 13                   Shake That (From "Kakki Sattai")
# 14      VIP Title Song (From "Velaiyilla Pattathari")
# 15                                        Vaathi Raid
# 16                            Every Girl I Ever Loved
# 17                  I'm So cool (From "Kakki Sattai")
# 18                                       Meet The Man
# 19              Thangamey (From "Naanum Rowdy Dhaan")
# 20        Varavaa Varavaa (From "Naanum Rowdy Dhaan")
# 21                                       Quit Pannuda
# 22                     Hello Beautiful - 2020 Version
# 23                                            Shallow
# 24                      Beat of Master - Instrumental
# 25                          Chellamma (From "Doctor")
# 26                                     Balam Pichkari
# 27                  Putham Pudhu Kaalai - Title Track
# 28                                      Nagada Nagada
# 29                 Tum Hi Ho Bandhu (From "Cocktail")
# 30                                     Illegal Weapon
# 31                                      Dhadak Dhadak
# 32                                      Kanave Kanave
# 33                               Just the Way You Are
# 34                                           Cutiepie
# 35                                            TiK ToK
# 36                               Love The Way You Lie
# 37                                           Dynamite
# 38                                      Dance Basanti
# 39                     London Thumakda (From "Queen")
# 40                           Feel Again (Feat. Au/Ra)
# 41                                      Bole Chudiyan
# 42                  Dj Waley Babu (feat. Aastha Gill)
# 43                                       Daru Badnaam
# 44             Kaattu Payale (From "Soorarai Pottru")
# 45              Veyyon Silli (From "Soorarai Pottru")
# 46                     Coca Cola (From "Luka Chuppi")
# 47                                          Suit Suit
# 48    Rakita Rakita Rakita (From "Jagame Thandhiram")
# 49  Kar Gayi Chull (From "Kapoor & Sons (Since 192...
#
#                                                 album                track_id  \
# 0         Master (Original Motion Picture Soundtrack)  2BcPFQ7nrtUObgAs72xaac
# 1                                        Voice of Ani  34hssXUwRCru1RbfxCWLth
# 2                                    Noah Schnacky EP  04hHPq6kXTbcSSDrdaP3s4
# 3         Master (Original Motion Picture Soundtrack)  0qvoxfYodIfe14gaidhnsV
# 4                                     All the Cowboys  13TOvHAfdO8wryqxBL7fnI
# 5                                          Wilderness  1MOOJuxUu9QiQE9GgkYYPb
# 6                                    Noah Schnacky EP  1wr0HUe5tFDlN32jfwt9IS
# 7                                    Noah Schnacky EP  26LKaGfw6ZolgGArPDEN2R
# 8         Master (Original Motion Picture Soundtrack)  2K058s9yrpoUfANaQt7Zu4
# 9                                        Voice of Ani  2XMJ3A06ex0UI9JRPeOYrQ
# 10        Master (Original Motion Picture Soundtrack)  2dnAqKYsZRuNVOJ9OVH7Ov
# 11                                       Voice of Ani  3HTKAcHglpt5HVwJKla9aT
# 12                                       Voice of Ani  3K1ee0j1artF9aL9M7cZst
# 13                                       Voice of Ani  3LSuyxVFp5sLUdZIflhsWs
# 14                                       Voice of Ani  3rtpnMDvzcE0FRHALqaX3M
# 15        Master (Original Motion Picture Soundtrack)  4PML5RtrVcYAwTTS46otXB
# 16                            Every Girl I Ever Loved  4fbnx3oevoht9LNrauDsVP
# 17                                       Voice of Ani  4kR4T5BFpb6unE1ivbgDfI
# 18                                   Noah Schnacky EP  54iGR32Ba6mRtwLASLkohd
# 19                                       Voice of Ani  56bFCJnXMcET6BwVZyJaGO
# 20                                       Voice of Ani  5ktYErU0EKwvpen8FDbnaT
# 21        Master (Original Motion Picture Soundtrack)  66N9OkT3uarJxuzD7iU4BP
# 22                                   Noah Schnacky EP  6PZR4jQ09UmM9hphbIblQQ
# 23                                            Shallow  6ysfrXnADdeTtW20oSybln
# 24        Master (Original Motion Picture Soundtrack)  7wQR696XF4L91Zr9groP8v
# 25                          Chellamma (From "Doctor")  0fGclndst25Qqy8j4u5De5
# 26                            Yeh Jawaani Hai Deewani  18e3XXYCv4Tx8uUl1mP3CN
# 27  Putham Pudhu Kaalai (Original Motion Picture S...  2W52SfioS5I4a1DZ734Kuq
# 28                                         Jab We Met  2W6bC4K4e6y42HnYTA5yHO
# 29                                           Cocktail  2zZTXtLqCsICzEcztKjn47
# 30                                     Illegal Weapon  3Oe3VdPn6rAueriQvFhCBA
# 31                         Bunty Aur Babli (Original)  6kOuIhlzgPlqlrWPudpSHL
# 32                                              David  6sPW145Y3LSXd4p1LjBOcS
# 33                               Doo-Wops & Hooligans  7BqBn9nzAq8spo5e7cZ0dJ
# 34  Ae Dil Hai Mushkil (Original Motion Picture So...  7hXnhouVPnOnFwCGrQMHvB
# 35                          Animal (Expanded Edition)  0HPD5WQqrq7wPWR7P7Dw1i
# 36                                           Recovery  15JINEqzVMv3SvJTAXAKED
# 37                                           Rokstarr  1DqdF42leyFIzqNDv9CjId
# 38         Ungli (Original Motion Picture Soundtrack)  1NxlktIRgiAPJ8U06v9veI
# 39                                Best Of Neha Kakkar  1VY2incfH4TLT9PCbot6lj
# 40                        Things I Wanted To Tell You  1fgC2MHbJnPgvDfdTpC62c
# 41  Kabhi Khushi Kabhie Gham (Original Motion Pict...  1uzkWkIaWaxzHJgJ4Fy5rO
# 42                  Dj Waley Babu (feat. Aastha Gill)  2SRv30X7NoYRZB62dX0UzH
# 43                                       Daru Badnaam  2TzyJEUfWHGRsk3r6Emvbk
# 44             Kaattu Payale (From "Soorarai Pottru")  2b4nWymybHj38A6XtQijiA
# 45              Veyyon Silli (From "Soorarai Pottru")  2gqapLp6Br7jcR1QQNBVFz
# 46                                     Dance Syndrome  2hOlxSH3Zck6a2ki4xtKGV
# 47                              Hits Of Guru Randhawa  2mwBSO58y92EYmEFpDfmS7
# 48    Rakita Rakita Rakita (From "Jagame Thandhiram")  2oNRoniEFnPdaCfkOQ9m0C
# 49  Kar Gayi Chull (From "Kapoor & Sons (Since 192...  3Q8yDujnXxwRiZ4p6VqY7b
#
#                  artist  duration  popularity
# 0   Anirudh Ravichander    228257          63
# 1   Anirudh Ravichander    117788          24
# 2         Noah Schnacky    174760          53
# 3   Anirudh Ravichander    194500          65
# 4         Alexandra Kay    228231          55
# 5      Spencer Crandall    177000          59
# 6         Noah Schnacky    168240          49
# 7         Noah Schnacky    190440          43
# 8   Anirudh Ravichander    214124          55
# 9   Anirudh Ravichander    301951          21
# 10  Anirudh Ravichander     97000          52
# 11  Anirudh Ravichander    256734          22
# 12  Anirudh Ravichander    209640          22
# 13  Anirudh Ravichander    183375          20
# 14  Anirudh Ravichander    236555          21
# 15  Anirudh Ravichander    209500          65
# 16        Noah Schnacky    162891          71
# 17  Anirudh Ravichander    229431          22
# 18        Noah Schnacky    230426          56
# 19  Anirudh Ravichander    262539          23
# 20  Anirudh Ravichander    202378          22
# 21  Anirudh Ravichander    256576          57
# 22        Noah Schnacky    232240          46
# 23    Danielle Bradbery    207746          59
# 24  Anirudh Ravichander     75500          54
# 25  Anirudh Ravichander    236500          70
# 26       Vishal Dadlani    288902          61
# 27        G. V. Prakash    297834          49
# 28           Sonu Nigam    228469          49
# 29      Neeraj Shridhar    282012          53
# 30         Garry Sandhu    230000          63
# 31         Udit Narayan    392411          38
# 32  Anirudh Ravichander    284784          64
# 33           Bruno Mars    220733          82
# 34               Pritam    231562          62
# 35                Kesha    199693          83
# 36               Eminem    263373          84
# 37            Taio Cruz    203866          73
# 38         Sachin-Jigar    223991          55
# 39          Labh Janjua    230468          52
# 40                 Kina    139354          65
# 41          Jatin-Lalit    408133          62
# 42              Badshah    169080          55
# 43          Param Singh    185333          65
# 44        G. V. Prakash    246000          68
# 45        G. V. Prakash    304000          64
# 46          Tony Kakkar    179225          54
# 47        Guru Randhawa    190131          64
# 48   Santhosh Narayanan    247455          67
# 49              Badshah    187710          52

# %% [markdown]
# ## Features Extraction

# %%
def get_features(sp,df):
    playlist = df[['track_id','track_name']]
    features = []
    
    features += sp.audio_features(playlist.iloc[0:50, 0])

    feature_list = []
    for feature in features:
        feature_list.append([feature['danceability'],
                        feature['energy'],
                        feature['key'],
                        feature['loudness'],
                        feature['mode'],
                        feature['speechiness'],
                        feature['acousticness'],
                        feature['instrumentalness'],
                        feature['liveness'],
                        feature['valence'],
                        feature['tempo'],
                        feature['duration_ms']]
                       )

    df_audio_feature = pd.DataFrame(feature_list, columns = ['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 
                                                          'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
                                                          'duration_ms'])
    df_playlist_audio_features = pd.concat([playlist, df_audio_feature], axis=1)
    return df_playlist_audio_features

# %%
df_final_features = get_features(sp,df_top_tracks)
#Drop the mode feature as it is binary
del df_final_features['mode']
df_final_features
# Out:
#                   track_id                                         track_name  \
# 0   2BcPFQ7nrtUObgAs72xaac                                      Vaathi Coming
# 1   34hssXUwRCru1RbfxCWLth       Ey Inge Paaru (From "Velaiyilla Pattathari")
# 2   04hHPq6kXTbcSSDrdaP3s4                                    Feels Like Love
# 3   0qvoxfYodIfe14gaidhnsV                             Andha Kanna Paathaakaa
# 4   13TOvHAfdO8wryqxBL7fnI                                    All the Cowboys
# 5   1MOOJuxUu9QiQE9GgkYYPb                                          My Person
# 6   1wr0HUe5tFDlN32jfwt9IS                                           Comeback
# 7   26LKaGfw6ZolgGArPDEN2R                       Maybe We Will - 2020 Version
# 8   2K058s9yrpoUfANaQt7Zu4                               Polakattum Para Para
# 9   2XMJ3A06ex0UI9JRPeOYrQ          Neeyum Naanum (From "Naanum Rowdy Dhaan")
# 10  2dnAqKYsZRuNVOJ9OVH7Ov                                      Pona Pogattum
# 11  3HTKAcHglpt5HVwJKla9aT          Kadhal Kan Kattudhe (From "Kakki Sattai")
# 12  3K1ee0j1artF9aL9M7cZst     Udhungada Sangu (From "Velaiyilla Pattathari")
# 13  3LSuyxVFp5sLUdZIflhsWs                   Shake That (From "Kakki Sattai")
# 14  3rtpnMDvzcE0FRHALqaX3M      VIP Title Song (From "Velaiyilla Pattathari")
# 15  4PML5RtrVcYAwTTS46otXB                                        Vaathi Raid
# 16  4fbnx3oevoht9LNrauDsVP                            Every Girl I Ever Loved
# 17  4kR4T5BFpb6unE1ivbgDfI                  I'm So cool (From "Kakki Sattai")
# 18  54iGR32Ba6mRtwLASLkohd                                       Meet The Man
# 19  56bFCJnXMcET6BwVZyJaGO              Thangamey (From "Naanum Rowdy Dhaan")
# 20  5ktYErU0EKwvpen8FDbnaT        Varavaa Varavaa (From "Naanum Rowdy Dhaan")
# 21  66N9OkT3uarJxuzD7iU4BP                                       Quit Pannuda
# 22  6PZR4jQ09UmM9hphbIblQQ                     Hello Beautiful - 2020 Version
# 23  6ysfrXnADdeTtW20oSybln                                            Shallow
# 24  7wQR696XF4L91Zr9groP8v                      Beat of Master - Instrumental
# 25  0fGclndst25Qqy8j4u5De5                          Chellamma (From "Doctor")
# 26  18e3XXYCv4Tx8uUl1mP3CN                                     Balam Pichkari
# 27  2W52SfioS5I4a1DZ734Kuq                  Putham Pudhu Kaalai - Title Track
# 28  2W6bC4K4e6y42HnYTA5yHO                                      Nagada Nagada
# 29  2zZTXtLqCsICzEcztKjn47                 Tum Hi Ho Bandhu (From "Cocktail")
# 30  3Oe3VdPn6rAueriQvFhCBA                                     Illegal Weapon
# 31  6kOuIhlzgPlqlrWPudpSHL                                      Dhadak Dhadak
# 32  6sPW145Y3LSXd4p1LjBOcS                                      Kanave Kanave
# 33  7BqBn9nzAq8spo5e7cZ0dJ                               Just the Way You Are
# 34  7hXnhouVPnOnFwCGrQMHvB                                           Cutiepie
# 35  0HPD5WQqrq7wPWR7P7Dw1i                                            TiK ToK
# 36  15JINEqzVMv3SvJTAXAKED                               Love The Way You Lie
# 37  1DqdF42leyFIzqNDv9CjId                                           Dynamite
# 38  1NxlktIRgiAPJ8U06v9veI                                      Dance Basanti
# 39  1VY2incfH4TLT9PCbot6lj                     London Thumakda (From "Queen")
# 40  1fgC2MHbJnPgvDfdTpC62c                           Feel Again (Feat. Au/Ra)
# 41  1uzkWkIaWaxzHJgJ4Fy5rO                                      Bole Chudiyan
# 42  2SRv30X7NoYRZB62dX0UzH                  Dj Waley Babu (feat. Aastha Gill)
# 43  2TzyJEUfWHGRsk3r6Emvbk                                       Daru Badnaam
# 44  2b4nWymybHj38A6XtQijiA             Kaattu Payale (From "Soorarai Pottru")
# 45  2gqapLp6Br7jcR1QQNBVFz              Veyyon Silli (From "Soorarai Pottru")
# 46  2hOlxSH3Zck6a2ki4xtKGV                     Coca Cola (From "Luka Chuppi")
# 47  2mwBSO58y92EYmEFpDfmS7                                          Suit Suit
# 48  2oNRoniEFnPdaCfkOQ9m0C    Rakita Rakita Rakita (From "Jagame Thandhiram")
# 49  3Q8yDujnXxwRiZ4p6VqY7b  Kar Gayi Chull (From "Kapoor & Sons (Since 192...
#
#     danceability  energy  key  loudness  speechiness  acousticness  \
# 0          0.643   0.952    7    -4.150       0.2460       0.27600
# 1          0.643   0.834    7    -4.104       0.1820       0.06520
# 2          0.639   0.845    2    -5.139       0.0414       0.00117
# 3          0.747   0.860    6    -4.071       0.2790       0.30100
# 4          0.501   0.554    9    -6.292       0.0265       0.32100
# 5          0.567   0.753    7    -5.291       0.0487       0.08940
# 6          0.542   0.817   11    -5.192       0.0324       0.03830
# 7          0.685   0.485    4    -7.755       0.0272       0.15100
# 8          0.758   0.796   11    -6.483       0.1700       0.16500
# 9          0.572   0.620    9    -9.949       0.0436       0.10100
# 10         0.685   0.476    0    -9.573       0.0369       0.83000
# 11         0.615   0.537    2    -4.951       0.0295       0.57200
# 12         0.519   0.806    8    -5.552       0.1180       0.21400
# 13         0.833   0.861    8    -4.220       0.1850       0.18100
# 14         0.547   0.931    0    -4.364       0.0879       0.00719
# 15         0.806   0.930    4    -3.404       0.1320       0.25300
# 16         0.649   0.598    1    -6.684       0.1510       0.05030
# 17         0.601   0.876    6    -4.733       0.2090       0.46600
# 18         0.599   0.722    9    -5.911       0.0309       0.04480
# 19         0.586   0.907    2    -5.774       0.0773       0.50000
# 20         0.764   0.805    1    -7.279       0.0730       0.12100
# 21         0.510   0.797    6    -5.279       0.2340       0.17900
# 22         0.549   0.512    9    -8.470       0.0283       0.17300
# 23         0.561   0.673    7    -4.186       0.0278       0.23200
# 24         0.844   0.961    2    -5.095       0.1110       0.25600
# 25         0.498   0.679    4    -7.252       0.2140       0.25600
# 26         0.732   0.944    0    -4.115       0.0900       0.20900
# 27         0.429   0.566    0   -10.003       0.0416       0.40200
# 28         0.757   0.942    9    -4.130       0.0461       0.15700
# 29         0.714   0.892   11    -5.342       0.0516       0.00145
# 30         0.814   0.666    6    -6.555       0.0635       0.48800
# 31         0.760   0.807    6    -5.603       0.0866       0.30400
# 32         0.470   0.513    9   -10.076       0.0294       0.37300
# 33         0.637   0.843    5    -5.413       0.0432       0.01510
# 34         0.799   0.929    0    -3.231       0.0668       0.25300
# 35         0.755   0.837    2    -2.718       0.1420       0.09910
# 36         0.749   0.925   10    -5.034       0.2270       0.24100
# 37         0.754   0.804    4    -3.177       0.0853       0.00332
# 38         0.833   0.740    6    -4.513       0.1290       0.16600
# 39         0.835   0.718    0    -6.614       0.0816       0.36300
# 40         0.487   0.384    5   -10.594       0.0587       0.24000
# 41         0.590   0.875    5    -5.294       0.1710       0.45000
# 42         0.959   0.606    1    -5.754       0.2190       0.34500
# 43         0.541   0.676    8    -3.893       0.1530       0.44200
# 44         0.700   0.631    2    -8.377       0.2120       0.32500
# 45         0.669   0.606    6    -9.284       0.0429       0.20400
# 46         0.722   0.867    0    -3.652       0.0904       0.12100
# 47         0.767   0.869    2    -3.381       0.0908       0.14000
# 48         0.790   0.740   10    -7.505       0.1680       0.58100
# 49         0.827   0.737   11    -5.473       0.0764       0.03160
#
#     instrumentalness  liveness  valence    tempo  duration_ms
# 0           0.490000    0.0588    0.585  164.784       228258
# 1           0.000042    0.6120    0.872  189.998       117788
# 2           0.000000    0.1260    0.703  117.047       174760
# 3           0.038300    0.0743    0.625   90.445       194500
# 4           0.000000    0.1780    0.470  144.022       228232
# 5           0.000000    0.1300    0.756  165.966       177000
# 6           0.000000    0.2180    0.683   95.978       168240
# 7           0.000000    0.1100    0.526   85.045       190440
# 8           0.000041    0.2900    0.919  145.475       214125
# 9           0.004880    0.1130    0.345  157.968       301951
# 10          0.257000    0.0920    0.601  142.411        97000
# 11          0.000000    0.1360    0.497  139.629       256735
# 12          0.000000    0.0640    0.714  171.942       209640
# 13          0.000046    0.2770    0.816   99.955       183375
# 14          0.000000    0.8800    0.740   89.999       236555
# 15          0.000019    0.1060    0.666  100.016       209500
# 16          0.000000    0.0964    0.576  189.933       162891
# 17          0.000000    0.1800    0.819   87.600       229432
# 18          0.000002    0.1060    0.593  150.022       230427
# 19          0.000000    0.2430    0.627   99.909       262540
# 20          0.000000    0.0440    0.659  129.989       202379
# 21          0.000000    0.4430    0.499   76.965       256577
# 22          0.000000    0.1820    0.299  148.084       232240
# 23          0.000000    0.0829    0.326   95.989       207747
# 24          0.880000    0.0894    0.547  172.429        75500
# 25          0.000325    0.0589    0.743   99.702       236500
# 26          0.000000    0.4030    0.957  120.019       288903
# 27          0.000025    0.1060    0.314  159.915       297835
# 28          0.007900    0.5070    0.727  120.006       228469
# 29          0.000817    0.0462    0.899  134.997       282012
# 30          0.000042    0.1080    0.714   94.020       230000
# 31          0.000000    0.1100    0.562  113.975       392411
# 32          0.000006    0.1230    0.477   95.015       284784
# 33          0.000000    0.0876    0.434  109.012       220733
# 34          0.000462    0.2400    0.952  127.999       231562
# 35          0.000000    0.2890    0.714  120.028       199693
# 36          0.000000    0.5200    0.641   86.989       263373
# 37          0.000000    0.0329    0.818  119.968       203867
# 38          0.000003    0.3630    0.804  103.035       223992
# 39          0.000919    0.0625    0.640  139.968       230468
# 40          0.000000    0.1240    0.224   78.138       139355
# 41          0.000012    0.1640    0.736   96.915       408133
# 42          0.000000    0.1260    0.783  110.000       169080
# 43          0.000000    0.1590    0.845   90.037       185333
# 44          0.000246    0.3760    0.490   78.924       246000
# 45          0.000000    0.3720    0.653  119.998       304000
# 46          0.005200    0.1230    0.893  102.009       179225
# 47          0.000000    0.2210    0.751   98.208       190132
# 48          0.000165    0.5230    0.948  133.526       247455
# 49          0.000322    0.2110    0.873  121.990       187711

# %% [markdown]
# ## EDA Performed

# %% [markdown]
# ## Featured Playlists Extraction

# %%
def featured_playlists(sp):
    id = []
    name = []
    num_tracks = []
    
    featured = sp.featured_playlists()
    playlists = featured['playlists']
    for i, items in enumerate(playlists['items']):
        id.append(items['id'])
        name.append(items['name'])
        num_tracks.append(items['tracks']['total'])
    
    df_playlists = pd.DataFrame({'playlist_id':id, 'playlist_name':name, '#tracks': num_tracks})
    return df_playlists

# %%
df_featured_playlists = featured_playlists(sp)
df_featured_playlists
# Out:
#                playlist_id         playlist_name  #tracks
# 0   37i9dQZF1DXcBWIGoYBM5M      Today's Top Hits       50
# 1   37i9dQZF1DX4bSrsRWE9cd                 Bliss       74
# 2   37i9dQZF1DWYmVQ81PeQpL  Dance The Night Away      128
# 3   37i9dQZF1DX1gRalH1mWrP           Summer Hits       99
# 4   37i9dQZF1DWVinJBuv0P4z    Feel Good Classics       80
# 5   37i9dQZF1DXcWBRiUaG3o5      Evening Acoustic      115
# 6   37i9dQZF1DXdPec7aLTmlC           Happy Hits!      100
# 7   37i9dQZF1DWWvhKV4FBciw  Funk & Soul Classics       80
# 8   37i9dQZF1DWTJ7xPn4vNaz           All Out 70s      150
# 9   37i9dQZF1DX36Xw4IJIVKA          Lofi Hip-Hop      100
# 10  37i9dQZF1DXdpVGstUksUC           Stoner Rock      150
# 11  37i9dQZF1DX9XIFQuFvzM4          Feelin' Good      100

# %% [markdown]
# ## Fetch Tracks for each playlists

# %%
def get_playlist_tracks(sp, playlist_id):
    tracks = []
    offset = 0
    while True:
        track_list = sp.playlist_tracks(playlist_id, fields = None, limit = 100, offset = offset, market = None)
        tracks += track_list['items']
        
        if track_list['next'] is not None:
            offset +=100
        else:
            break
            
    track_id = []
    track_name = []
    
    for track in tracks:
        track_id.append(track['track']['id'])
        track_name.append(track['track']['name'])
    
    df_playlist_tracks = pd.DataFrame({'track_id':track_id, 'track_name': track_name})
    return df_playlist_tracks

# %% [markdown]
# ## Get Audio Features for each track within a playlist

# %%
def get_audio_features(sp, playlist_id):
    playlist = get_playlist_tracks(sp, playlist_id)
    audio_features = []
    index = 0
    while index < playlist.shape[0]:
        audio_features += sp.audio_features(playlist.iloc[index:index + 50, 0])
        index += 50
    
    feature_list = []
    for feature in audio_features:
        feature_list.append([feature['danceability'],
                        feature['energy'],
                        feature['key'],
                        feature['loudness'],
#                         feature['mode'],
                        feature['speechiness'],
                        feature['acousticness'],
                        feature['instrumentalness'],
                        feature['liveness'],
                        feature['valence'],
                        feature['tempo'],
                        feature['duration_ms']]
                       )

    df_audio_feature = pd.DataFrame(feature_list, columns = ['danceability', 'energy', 'key', 'loudness', 'speechiness', 
                                                          'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
                                                          'duration_ms'])
    df_playlist_audio_features = pd.concat([playlist, df_audio_feature], axis=1)
    return df_playlist_audio_features

# %% [markdown]
# ## Get the mean & merge each playlist

# %%
def get_audio_features_mean (sp, playlist_id):
    playlist = get_audio_features(sp, playlist_id)
    df_mean_playlist = pd.DataFrame(playlist.mean(),columns = [playlist_id])
    return df_mean_playlist

# %%
dataframes = []
for i in df_featured_playlists['playlist_id']:
    dataframes.append(get_audio_features_mean(sp, i))
    
dataframes
# Out:
# [                  37i9dQZF1DXcBWIGoYBM5M
#  danceability                    0.705500
#  energy                          0.608620
#  key                             4.860000
#  loudness                       -6.552220
#  speechiness                     0.098234
#  acousticness                    0.281415
#  instrumentalness                0.003869
#  liveness                        0.152266
#  valence                         0.512672
#  tempo                         119.009120
#  duration_ms                183441.380000,
#                    37i9dQZF1DX4bSrsRWE9cd
#  danceability                    0.495473
#  energy                          0.235396
#  key                             3.770270
#  loudness                      -14.778986
#  speechiness                     0.038682
#  acousticness                    0.816699
#  instrumentalness                0.164258
#  liveness                        0.133188
#  valence                         0.248828
#  tempo                         117.758108
#  duration_ms                231246.891892,
#                    37i9dQZF1DWYmVQ81PeQpL
#  danceability                    0.718773
#  energy                          0.777055
#  key                             5.734375
#  loudness                       -6.727828
#  speechiness                     0.072946
#  acousticness                    0.118999
#  instrumentalness                0.038717
#  liveness                        0.192106
#  valence                         0.707461
#  tempo                         118.780039
#  duration_ms                225965.007812,
#                    37i9dQZF1DX1gRalH1mWrP
#  danceability                    0.705374
#  energy                          0.653465
#  key                             5.121212
#  loudness                       -6.102586
#  speechiness                     0.111174
#  acousticness                    0.199946
#  instrumentalness                0.009961
#  liveness                        0.185335
#  valence                         0.523758
#  tempo                         118.262667
#  duration_ms                186197.717172,
#                    37i9dQZF1DWVinJBuv0P4z
#  danceability                    0.615900
#  energy                          0.640150
#  key                             5.400000
#  loudness                       -8.531400
#  speechiness                     0.052376
#  acousticness                    0.415748
#  instrumentalness                0.011213
#  liveness                        0.175160
#  valence                         0.795175
#  tempo                         118.272075
#  duration_ms                176384.012500,
#                    37i9dQZF1DXcWBRiUaG3o5
#  danceability                    0.489661
#  energy                          0.227158
#  key                             4.539130
#  loudness                      -14.056017
#  speechiness                     0.039552
#  acousticness                    0.852304
#  instrumentalness                0.107887
#  liveness                        0.146652
#  valence                         0.263305
#  tempo                         115.723235
#  duration_ms                233165.495652,
#                    37i9dQZF1DXdPec7aLTmlC
#  danceability                    0.674620
#  energy                          0.707730
#  key                             5.210000
#  loudness                       -5.528200
#  speechiness                     0.077673
#  acousticness                    0.150887
#  instrumentalness                0.001847
#  liveness                        0.184725
#  valence                         0.561510
#  tempo                         117.758430
#  duration_ms                187713.510000,
#                    37i9dQZF1DWWvhKV4FBciw
#  danceability                    0.621862
#  energy                          0.659925
#  key                             4.937500
#  loudness                       -8.775563
#  speechiness                     0.061507
#  acousticness                    0.325953
#  instrumentalness                0.095204
#  liveness                        0.208363
#  valence                         0.767450
#  tempo                         122.904837
#  duration_ms                216373.050000,
#                    37i9dQZF1DWTJ7xPn4vNaz
#  danceability                    0.582960
#  energy                          0.568939
#  key                             5.446667
#  loudness                      -10.151387
#  speechiness                     0.049112
#  acousticness                    0.356825
#  instrumentalness                0.025934
#  liveness                        0.171027
#  valence                         0.642489
#  tempo                         119.528300
#  duration_ms                226801.740000,
#                    37i9dQZF1DX36Xw4IJIVKA
#  danceability                    0.679340
#  energy                          0.386300
#  key                             5.570000
#  loudness                      -11.387890
#  speechiness                     0.128608
#  acousticness                    0.521623
#  instrumentalness                0.657354
#  liveness                        0.182511
#  valence                         0.428818
#  tempo                         104.773510
#  duration_ms                133163.450000,
#                    37i9dQZF1DXdpVGstUksUC
#  danceability                    0.327607
#  energy                          0.738940
#  key                             5.480000
#  loudness                       -7.476233
#  speechiness                     0.050639
#  acousticness                    0.040539
#  instrumentalness                0.405376
#  liveness                        0.182473
#  valence                         0.324705
#  tempo                         123.838360
#  duration_ms                343320.193333,
#                    37i9dQZF1DX9XIFQuFvzM4
#  danceability                    0.634130
#  energy                          0.618200
#  key                             4.720000
#  loudness                       -8.249700
#  speechiness                     0.048955
#  acousticness                    0.370497
#  instrumentalness                0.022004
#  liveness                        0.193628
#  valence                         0.757670
#  tempo                         119.539940
#  duration_ms                185849.210000]

# %%
#Combines the 
X = reduce(lambda left,right: pd.merge(left,right, left_index=True, right_index=True), dataframes)
X
# Out:
#                   37i9dQZF1DXcBWIGoYBM5M  37i9dQZF1DX4bSrsRWE9cd  \
# danceability                    0.705500                0.495473
# energy                          0.608620                0.235396
# key                             4.860000                3.770270
# loudness                       -6.552220              -14.778986
# speechiness                     0.098234                0.038682
# acousticness                    0.281415                0.816699
# instrumentalness                0.003869                0.164258
# liveness                        0.152266                0.133188
# valence                         0.512672                0.248828
# tempo                         119.009120              117.758108
# duration_ms                183441.380000           231246.891892
#
#                   37i9dQZF1DWYmVQ81PeQpL  37i9dQZF1DX1gRalH1mWrP  \
# danceability                    0.718773                0.705374
# energy                          0.777055                0.653465
# key                             5.734375                5.121212
# loudness                       -6.727828               -6.102586
# speechiness                     0.072946                0.111174
# acousticness                    0.118999                0.199946
# instrumentalness                0.038717                0.009961
# liveness                        0.192106                0.185335
# valence                         0.707461                0.523758
# tempo                         118.780039              118.262667
# duration_ms                225965.007812           186197.717172
#
#                   37i9dQZF1DWVinJBuv0P4z  37i9dQZF1DXcWBRiUaG3o5  \
# danceability                    0.615900                0.489661
# energy                          0.640150                0.227158
# key                             5.400000                4.539130
# loudness                       -8.531400              -14.056017
# speechiness                     0.052376                0.039552
# acousticness                    0.415748                0.852304
# instrumentalness                0.011213                0.107887
# liveness                        0.175160                0.146652
# valence                         0.795175                0.263305
# tempo                         118.272075              115.723235
# duration_ms                176384.012500           233165.495652
#
#                   37i9dQZF1DXdPec7aLTmlC  37i9dQZF1DWWvhKV4FBciw  \
# danceability                    0.674620                0.621862
# energy                          0.707730                0.659925
# key                             5.210000                4.937500
# loudness                       -5.528200               -8.775563
# speechiness                     0.077673                0.061507
# acousticness                    0.150887                0.325953
# instrumentalness                0.001847                0.095204
# liveness                        0.184725                0.208363
# valence                         0.561510                0.767450
# tempo                         117.758430              122.904837
# duration_ms                187713.510000           216373.050000
#
#                   37i9dQZF1DWTJ7xPn4vNaz  37i9dQZF1DX36Xw4IJIVKA  \
# danceability                    0.582960                0.679340
# energy                          0.568939                0.386300
# key                             5.446667                5.570000
# loudness                      -10.151387              -11.387890
# speechiness                     0.049112                0.128608
# acousticness                    0.356825                0.521623
# instrumentalness                0.025934                0.657354
# liveness                        0.171027                0.182511
# valence                         0.642489                0.428818
# tempo                         119.528300              104.773510
# duration_ms                226801.740000           133163.450000
#
#                   37i9dQZF1DXdpVGstUksUC  37i9dQZF1DX9XIFQuFvzM4
# danceability                    0.327607                0.634130
# energy                          0.738940                0.618200
# key                             5.480000                4.720000
# loudness                       -7.476233               -8.249700
# speechiness                     0.050639                0.048955
# acousticness                    0.040539                0.370497
# instrumentalness                0.405376                0.022004
# liveness                        0.182473                0.193628
# valence                         0.324705                0.757670
# tempo                         123.838360              119.539940
# duration_ms                343320.193333           185849.210000

# %%
y = pd.DataFrame(df_final_features.mean(), columns = ['top_playlist'])
y
# Out:
#                    top_playlist
# danceability           0.671060
# energy                 0.754080
# key                    5.200000
# loudness              -5.817680
# speechiness            0.106166
# acousticness           0.235979
# instrumentalness       0.033735
# liveness               0.207758
# valence                0.661100
# tempo                120.519860
# duration_ms       222377.160000

# %% [markdown]
# ## Cosine Similarity

# %%
def cos_sim(a,b):
    dot_product = np.dot(a,b)
    norm_a = np.linalg.norm(a)
    norm_b = np.linalg.norm(b)
    return dot_product/(norm_a * norm_b)

# %%
#Cosine similarity does not look at the magnititudes of individual elements within the vector, just the angle
def similarities(user_playlist,featured_playlist):
    x = cos_sim(user_playlist,featured_playlist)
    return x

# %% [markdown]
# ## Euclidean Distance

# %%
#Euclidian distance takes the magnitude of each element within the vector into consideration 
def euclidean_distance(user_playlist,featured_playlist):    
    x = np.sqrt(np.sum((user_playlist - featured_playlist) ** 2))
    return x

# %%
def euc_dataframe(user_playlist):
    featured = []
    distance_score = []
    for i in df_featured_playlists['playlist_id']:
        featured.append(i)
        distance_score.append(euclidean_distance(user_playlist,X[i]))
    df_euc_dist = pd.DataFrame({'featured_playlist':featured, 'distance_score':distance_score})
    sort_values = df_euc_dist.sort_values('distance_score')
    return sort_values

# %%
euc_dataframe(y['top_playlist'])
# Out:
#          featured_playlist  distance_score
# 2   37i9dQZF1DWYmVQ81PeQpL     3587.848392
# 8   37i9dQZF1DWTJ7xPn4vNaz     4424.582247
# 7   37i9dQZF1DWWvhKV4FBciw     6004.111211
# 1   37i9dQZF1DX4bSrsRWE9cd     8869.737011
# 5   37i9dQZF1DXcWBRiUaG3o5    10788.339924
# 6   37i9dQZF1DXdPec7aLTmlC    34663.650112
# 3   37i9dQZF1DX1gRalH1mWrP    36179.442900
# 11  37i9dQZF1DX9XIFQuFvzM4    36527.950098
# 0   37i9dQZF1DXcBWIGoYBM5M    38935.780038
# 4   37i9dQZF1DWVinJBuv0P4z    45993.147636
# 9   37i9dQZF1DX36Xw4IJIVKA    89213.711568
# 10  37i9dQZF1DXdpVGstUksUC   120943.033392
